# %%
ls
# Out:
# IO与文件操作.ipynb  test1.exe  Untitled.ipynb  x2.txt  x3.txt  xxx.txt

# %%
ff = open('/root/staff.txt')

# %%
ff.readable()
# Out:
# True

# %%
ff.read()
# Out:
# 'bogon:sech sean$ cat staff.txt \nalex\tLi,\tEngineer,\tIT,\t13651054608,\talex@126.com\nJack\tZhang,\tSalesman,\tSales\tDep.,\t18546304334,\tjack@sina.com\nRain\tWang,\tHR,\tHR\tDep.,\t13345634253,\train@autohome.com.cn\nSean xin,\tEngineer,\tIT,\t13821172769,\tlinux_no1@126.com\n\nli\n\n#你好啊\n'

# %%
cat /root/staff.txt
# Out:
# bogon:sech sean$ cat staff.txt
# alex	Li,	Engineer,	IT,	13651054608,	alex@126.com
# Jack	Zhang,	Salesman,	Sales	Dep.,	18546304334,	jack@sina.com
# Rain	Wang,	HR,	HR	Dep.,	13345634253,	rain@autohome.com.cn
# Sean xin,	Engineer,	IT,	13821172769,	linux_no1@126.com
#
# li
#
# #你好啊

# %%
ff.read(10)
# Out:
# ''

# %%
ff.seek(0)
# Out:
# 0

# %%
ff.read(10)
# Out:
# 'bogon:sech'

# %%
ff.read(10)
# Out:
# ' sean$ cat'

# %%
ff.read(10)
# Out:
# ' staff.txt'

# %%
ff.read(10)
# Out:
# ' \nalex\tLi,'

# %%
ff.tell()
# Out:
# 40

# %%
ff.close()

# %%
ff = open('test1.exe','rb')

# %%
ff.read()
# Out:
# b'\xe9\x99\x88\xe9\x99\x88\xe9\x99\x88\xe9\x99\x881234'

# %%
ff.read()
# Out:
# b''

# %%
ff.seek(0)
# Out:
# 0

# %%
ff.read(3)
# Out:
# b'\xe9\x99\x88'

# %%
ff.close()

# %%
ff = open('test1.exe','rt')

# %%
ff.read(3)
# Out:
# '陈陈陈'

# %%
ff.close()

# %%
ls
# Out:
# IO与文件操作.ipynb  test1.exe  Untitled.ipynb  x2.txt  x3.txt  xxx.txt

# %%
cat test1.exe
# Out:
# 陈陈陈陈1234

# %%
ff = open('test1.exe','rt')

# %%
ff.readable()
# Out:
# True

# %%
ff.writable()
# Out:
# False

# %%
ff.close()

# %%
ff = open('test1.exe','r+t')

# %%
ff.readable()
# Out:
# True

# %%
ff.writable()
# Out:
# True

# %%
ff.close()

# %%
ls
# Out:
# IO与文件操作.ipynb  test1.exe  Untitled.ipynb  x2.txt  x3.txt  xxx.txt

# %%
cat x2.txt

# %%
ff = open('x2.txt','a+')

# %%
ff.read()
# Out:
# ''

# %%
ff.write('haha')
# Out:
# 4

# %%
cat x2.txt

# %%
ff.close()

# %%
cat x2.txt
# Out:
# haha

# %%
ff = open('x2.txt','a+')

# %%
ff.read()
# Out:
# ''

# %%
ff.write('xixi')
# Out:
# 4

# %%
cat x2.txt
# Out:
# haha

# %%
ff.close()

# %%
cat x2.txt
# Out:
# hahaxixi

# %%
ff = open('x2.txt','w+')

# %%
ff.close()

# %%
cat x2.txt

# %%
ls
# Out:
# gbk.txt  IO与文件操作.ipynb  test1.exe  Untitled.ipynb  x2.txt  x3.txt  xxx.txt

# %%
s = (1,2,3)

# %%
s[0]
# Out:
# 1

# %%
help(makefile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-81c2c72561b7> in <module>()
# ----> 1 help(makefile)
#
# NameError: name 'makefile' is not defined

# %%
import socket

# %%
help(makefile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-81c2c72561b7> in <module>()
# ----> 1 help(makefile)
#
# NameError: name 'makefile' is not defined

# %%
f = open('hello','w')

# %%
ls
# Out:
# gbk.txt  IO与文件操作.ipynb  Untitled.ipynb  x2.txt  xin.py*
# hello    test1.exe           utf8.txt        x3.txt  xxx.txt

# %%
cat hello

# %%
f.write('hello\n')
# Out:
# 6

# %%
cat hello

# %%
f.flush()

# %%
cat hello
# Out:
# hello

# %%
f.tell()
# Out:
# 6

# %%
f.write('haha')
# Out:
# 4

# %%
f.tell()
# Out:
# 10

# %%
f.close()

# %%
cat hello
# Out:
# hello
# haha

# %%
f = open('hello','a')

# %%
f.tell()
# Out:
# 10

# %%
f.write('xixi')
# Out:
# 4

# %%
f.flush()

# %%
cat hello
# Out:
# hello
# hahaxixi

# %%
f.seek(1)
# Out:
# 1

# %%
f.tell()
# Out:
# 1

# %%
f.write('nihao\n')
# Out:
# 6

# %%
f.tell()
# Out:
# 20

# %%
f.flush()

# %%
cat hello
# Out:
# hello
# hahaxixinihao

# %%
f.write('chenchen ')
# Out:
# 9

# %%
cat hello
# Out:
# hello
# hahaxixinihao

# %%
f.close()

# %%
cat hello
# Out:
# hello
# hahaxixinihao
# chenchen

# %%
ls
# Out:
# gbk.txt  IO与文件操作.ipynb  Untitled.ipynb  x2.txt  xin.py*
# hello    test1.exe           utf8.txt        x3.txt  xxx.txt

# %%
f = open('xin.py','r')

# %%
f.read()
# Out:
# "#!/usr/bin/env python\n#_*_ coding:utf-8 _*_\nimport os\nwhile True:\n\tprint '''\t\t \\033**************************************\\033\n\t\t \\033*\t1.Search\t\t      *\\033\n\t\t \\033*\t2.Add、Del、Change\t      *\\033\n\t\t \\033**************************************\\033'''\n\taction = int(raw_input('Please enter the number of your needs? '))\n\tif action == 1:\n\t\tcount_number = 0\n\t\tAction_One_Key = raw_input('Please enter a keyword query: ')\n\t\tF = file('staff.txt','r')\n\t\tfor line in F.readlines():\n\t\t\tif Action_One_Key in line:\n\t\t\t\tcount_number += 1\n\t\t\t\tline_strip = line.strip()\n\t\t\t\tprint '\\033 %s\\033' %line_strip\n\t\tprint '\\033count_number: %s\\033' %count_number\n\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n\t\tif Goon_key == 'n':\n\t\t\tbreak\n\telif action == 2:\n\t\tprint '''                 \\033**************************************\\033\n                 \\033*    1.Add                           *\\033\n                 \\033*    2.Del                           *\\033\n\t\t \\033*    3.Change                        *\\033\n                 \\033**************************************\\033'''\n\t\taction_2 = int(raw_input('Please enter the number of your needs? '))\n\t\tif action_2 == 1:\n\t\t\tinput_str = raw_input('Please enter the information you want to add employees: ')\n\t\t\tF_write = file('staff.txt','a')\n\t\t\tF_write.write('%s\\n'%input_str)\n\t\t\tF_write.close()\n\t\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n                \tif Goon_key == 'n':\n                        \tbreak\n\t\telif action_2 == 2:\n\t\t\tdel_str = raw_input('Please enter your user information to be deleted: ')\n\t\t\tF_del = file('staff.txt','r')\n\t\t\tF_del_new = file('staff_del_bak.txt','w')\n\t\t\tfor line in F_del.readlines():\n\t\t\t\tif del_str in line:\n\t\t\t\t\tcontinue\n\t\t\t\tF_del_new.write(line)\n\t\t\tF_del.close()\n\t\t\tF_del_new.close()\n\t\t\tos.rename('staff_del_bak.txt','staff.txt')\n\t\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n                        if Goon_key == 'n':\n                                break\n\t\telif action_2 == 3:\n\t\t\tinput_change_str = raw_input('Please enter your user information to be modified: ')\n\t\t\tinput_change_str2 = raw_input('Please enter the modified content: ')\n\t\t\tF_change_source = file('staff.txt','r')\n\t\t\tF_change_new = file('staff_change_bak.txt','w')\n\t\t\tfor line in  F_change_source.readlines():\n\t\t\t\tif input_change_str in line:\n\t\t\t\t\tline = line.replace(input_change_str,input_change_str2)\n\t\t\t\t\tprint line\n\t\t\t\tF_change_new.write('%s\\n'%line)\n\t\t\tF_change_source.close()\n\t\t\tF_change_new.close()\n\t\t\tos.rename('staff_change_bak.txt','staff.txt')\n\t\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n                        if Goon_key == 'n':\n                                break\n\t\telse:\n\t\t\tprint '\\033非法序列！请输入正确的操作符号！\\033'\n\telse:\n\t\tprint '\\033非法序列！请输入正确的操作符号！\\033'\n\n"

# %%
cat xin.py
# Out:
# #!/usr/bin/env python
# #_*_ coding:utf-8 _*_
# import os
# while True:
# 	print '''		 \033**************************************\033
# 		 \033*	1.Search		      *\033
# 		 \033*	2.Add、Del、Change	      *\033
# 		 \033**************************************\033'''
# 	action = int(raw_input('Please enter the number of your needs? '))
# 	if action == 1:
# 		count_number = 0
# 		Action_One_Key = raw_input('Please enter a keyword query: ')
# 		F = file('staff.txt','r')
# 		for line in F.readlines():
# 			if Action_One_Key in line:
# 				count_number += 1
# 				line_strip = line.strip()
# 				print '\033 %s\033' %line_strip
# 		print '\033count_number: %s\033' %count_number
# 		Goon_key = raw_input('Do you want to continue? (y|n) ')
# 		if Goon_key == 'n':
# 			break
# 	elif action == 2:
# 		print '''                 \033**************************************\033
#                  \033*    1.Add                           *\033
#                  \033*    2.Del                           *\033
# 		 \033*    3.Change                        *\033
#                  \033**************************************\033'''
# 		action_2 = int(raw_input('Please enter the number of your needs? '))
# 		if action_2 == 1:
# 			input_str = raw_input('Please enter the information you want to add employees: ')
# 			F_write = file('staff.txt','a')
# 			F_write.write('%s\n'%input_str)
# 			F_write.close()
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#                 	if Goon_key == 'n':
#                         	break
# 		elif action_2 == 2:
# 			del_str = raw_input('Please enter your user information to be deleted: ')
# 			F_del = file('staff.txt','r')
# 			F_del_new = file('staff_del_bak.txt','w')
# 			for line in F_del.readlines():
# 				if del_str in line:
# 					continue
# 				F_del_new.write(line)
# 			F_del.close()
# 			F_del_new.close()
# 			os.rename('staff_del_bak.txt','staff.txt')
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#                         if Goon_key == 'n':
#                                 break
# 		elif action_2 == 3:
# 			input_change_str = raw_input('Please enter your user information to be modified: ')
# 			input_change_str2 = raw_input('Please enter the modified content: ')
# 			F_change_source = file('staff.txt','r')
# 			F_change_new = file('staff_change_bak.txt','w')
# 			for line in  F_change_source.readlines():
# 				if input_change_str in line:
# 					line = line.replace(input_change_str,input_change_str2)
# 					print line
# 				F_change_new.write('%s\n'%line)
# 			F_change_source.close()
# 			F_change_new.close()
# 			os.rename('staff_change_bak.txt','staff.txt')
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#                         if Goon_key == 'n':
#                                 break
# 		else:
# 			print '\033非法序列！请输入正确的操作符号！\033'
# 	else:
# 		print '\033非法序列！请输入正确的操作符号！\033'

# %%
f.read(3)
# Out:
# ''

# %%
f.seek(10)
# Out:
# 10

# %%
f.read(3)
# Out:
# '/en'

# %%
f.read(10)
# Out:
# 'v python\n#'

# %%
f.tell()
# Out:
# 23

# %%
f.read(3)
# Out:
# ''

# %%
f.tell()
# Out:
# 2938

# %%
f.seek(10)
# Out:
# 10

# %%
f.tell()
# Out:
# 10

# %%
f.read(3)
# Out:
# '/en'

# %%
f
# Out:
# <_io.TextIOWrapper name='xin.py' mode='r' encoding='UTF-8'>

# %%
f.writable()
# Out:
# False

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'v python\n'

# %%
f.readlines()
# Out:
# ['#_*_ coding:utf-8 _*_\n',
#  'import os\n',
#  'while True:\n',
#  "\tprint '''\t\t \\033**************************************\\033\n",
#  '\t\t \\033*\t1.Search\t\t      *\\033\n',
#  '\t\t \\033*\t2.Add、Del、Change\t      *\\033\n',
#  "\t\t \\033**************************************\\033'''\n",
#  "\taction = int(raw_input('Please enter the number of your needs? '))\n",
#  '\tif action == 1:\n',
#  '\t\tcount_number = 0\n',
#  "\t\tAction_One_Key = raw_input('Please enter a keyword query: ')\n",
#  "\t\tF = file('staff.txt','r')\n",
#  '\t\tfor line in F.readlines():\n',
#  '\t\t\tif Action_One_Key in line:\n',
#  '\t\t\t\tcount_number += 1\n',
#  '\t\t\t\tline_strip = line.strip()\n',
#  "\t\t\t\tprint '\\033 %s\\033' %line_strip\n",
#  "\t\tprint '\\033count_number: %s\\033' %count_number\n",
#  "\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n",
#  "\t\tif Goon_key == 'n':\n",
#  '\t\t\tbreak\n',
#  '\telif action == 2:\n',
#  "\t\tprint '''                 \\033**************************************\\033\n",
#  '                 \\033*    1.Add                           *\\033\n',
#  '                 \\033*    2.Del                           *\\033\n',
#  '\t\t \\033*    3.Change                        *\\033\n',
#  "                 \\033**************************************\\033'''\n",
#  "\t\taction_2 = int(raw_input('Please enter the number of your needs? '))\n",
#  '\t\tif action_2 == 1:\n',
#  "\t\t\tinput_str = raw_input('Please enter the information you want to add employees: ')\n",
#  "\t\t\tF_write = file('staff.txt','a')\n",
#  "\t\t\tF_write.write('%s\\n'%input_str)\n",
#  '\t\t\tF_write.close()\n',
#  "\t\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n",
#  "                \tif Goon_key == 'n':\n",
#  '                        \tbreak\n',
#  '\t\telif action_2 == 2:\n',
#  "\t\t\tdel_str = raw_input('Please enter your user information to be deleted: ')\n",
#  "\t\t\tF_del = file('staff.txt','r')\n",
#  "\t\t\tF_del_new = file('staff_del_bak.txt','w')\n",
#  '\t\t\tfor line in F_del.readlines():\n',
#  '\t\t\t\tif del_str in line:\n',
#  '\t\t\t\t\tcontinue\n',
#  '\t\t\t\tF_del_new.write(line)\n',
#  '\t\t\tF_del.close()\n',
#  '\t\t\tF_del_new.close()\n',
#  "\t\t\tos.rename('staff_del_bak.txt','staff.txt')\n",
#  "\t\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n",
#  "                        if Goon_key == 'n':\n",
#  '                                break\n',
#  '\t\telif action_2 == 3:\n',
#  "\t\t\tinput_change_str = raw_input('Please enter your user information to be modified: ')\n",
#  "\t\t\tinput_change_str2 = raw_input('Please enter the modified content: ')\n",
#  "\t\t\tF_change_source = file('staff.txt','r')\n",
#  "\t\t\tF_change_new = file('staff_change_bak.txt','w')\n",
#  '\t\t\tfor line in  F_change_source.readlines():\n',
#  '\t\t\t\tif input_change_str in line:\n',
#  '\t\t\t\t\tline = line.replace(input_change_str,input_change_str2)\n',
#  '\t\t\t\t\tprint line\n',
#  "\t\t\t\tF_change_new.write('%s\\n'%line)\n",
#  '\t\t\tF_change_source.close()\n',
#  '\t\t\tF_change_new.close()\n',
#  "\t\t\tos.rename('staff_change_bak.txt','staff.txt')\n",
#  "\t\t\tGoon_key = raw_input('Do you want to continue? (y|n) ')\n",
#  "                        if Goon_key == 'n':\n",
#  '                                break\n',
#  '\t\telse:\n',
#  "\t\t\tprint '\\033非法序列！请输入正确的操作符号！\\033'\n",
#  '\telse:\n',
#  "\t\tprint '\\033非法序列！请输入正确的操作符号！\\033'\n",
#  '\n']

# %%
f.tell()
# Out:
# 2938

# %%
f.close()

# %%
f = open('hello','x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-54-48cc62758cf4> in <module>()
# ----> 1 f = open('hello','x')
#
# FileExistsError: [Errno 17] File exists: 'hello'

# %%
f = open('111','a')

# %%
f.write('123')
# Out:
# 3

# %%
f.flush()

# %%
cat 111
# Out:
# 123

# %%
f.close()

# %%
f = open('hello')

# %%
f.readline()
# Out:
# 'hello\n'

# %%
cat hello
# Out:
# hello
# hahaxixinihao
# chenchen

# %%
f.readline().rstrip('\n')
# Out:
# 'hahaxixinihao'

# %%
f.read()
# Out:
# 'chenchen '

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines().strip('\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-203a48bd787e> in <module>()
# ----> 1 f.readlines().strip('\n')
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
import os

# %%
os.stat('hello')
# Out:
# os.stat_result(st_mode=33188, st_ino=204065019, st_dev=64768, st_nlink=1, st_uid=0, st_gid=0, st_size=29, st_atime=1478006127, st_mtime=1478006125, st_ctime=1478006125)

# %%
ls
# Out:
# 111      hello               test1.exe       utf8.txt  x3.txt   xxx.txt
# gbk.txt  IO与文件操作.ipynb  Untitled.ipynb  x2.txt    xin.py*

# %%
cat utf8.txt
# Out:
# 123

# %%
f = open('haha.txt','w')

# %%
f.writelines(['12345\n','xixihaha\n'])

# %%
f.flush()

# %%
cat haha.txt
# Out:
# 12345
# xixihaha

# %%
f.write('{a}:1')
# Out:
# 5

# %%
f.flush()

# %%
cat haha.txt
# Out:
# 12345
# xixihaha
# {a}:1

# %%
f.close()

# %%
f.closed
# Out:
# True

# %%
f = open('haha.txt','ab')

# %%
f.write('666')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-532514d282b8> in <module>()
# ----> 1 f.write('666')
#
# TypeError: a bytes-like object is required, not 'str'

# %%
f.write(b'666')
# Out:
# 3

# %%
f.flush()

# %%
cat haha.txt
# Out:
# 12345
# xixihaha
# {a}:1666

# %%
f.closed
# Out:
# False

# %%
f.close()

# %%
f
# Out:
# <_io.BufferedWriter name='haha.txt'>

# %%
f = open('haha.txt','ab')

# %%
f
# Out:
# <_io.BufferedWriter name='haha.txt'>

# %%
f.closed
# Out:
# False

# %%
f.close()

# %%
f.close()

# %%
with open('haha.txt','a+') as fd:
    fd.write('111111111111')

# %%
cat haha.txt
# Out:
# 12345
# xixihaha
# {a}:1666111111111111

# %%
fd.closed
# Out:
# True

# %%
f.buffer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a9538f1014cf> in <module>()
# ----> 1 f.buffer
#
# AttributeError: '_io.BufferedWriter' object has no attribute 'buffer'

# %%
f.name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-f0ea48ccc8ff> in <module>()
# ----> 1 f.name()
#
# TypeError: 'str' object is not callable

# %%
f = open('haha.txt')

# %%
f.name
# Out:
# 'haha.txt'

# %%
f.encoding
# Out:
# 'UTF-8'

# %%
f.errors
# Out:
# 'strict'

# %%
f.newlines

# %%
f.fileno()
# Out:
# 49

# %%
from io import StringIO, BytesIO

# %%
sf = StringIO('testtest')

# %%
sf

# %%
sf.write('haha')
# Out:
# 4

# %%
print(sf.getvalue())
# Out:
# hahatest

# %%
help(f.makefile)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-fc2e1179dfd9> in <module>()
# ----> 1 help(f.makefile)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'makefile'

# %%
help(sf.makefile())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-0b076b76fd89> in <module>()
# ----> 1 help(sf.makefile())
#
# AttributeError: '_io.StringIO' object has no attribute 'makefile'

# %%
t = (1,2,3)

# %%
t[1]
# Out:
# 2

# %%
help(t.makefile)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-86cf7f60f885> in <module>()
# ----> 1 help(t.makefile)
#
# AttributeError: 'tuple' object has no attribute 'makefile'

# %%
import os

# %%
pwd
# Out:
# '/root/py3.5.2/python3.5.2/notes/6'

# %%
ls /tmp
# Out:
# a/  systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE/
# b/  systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4/
# c/  test/
# d/

# %%
os.mkdir('/tmp/123')

# %%
ls /tmp
# Out:
# 123/  d/
# a/    systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE/
# b/    systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4/
# c/    test/

# %%
import shutil

# %%
os.geteuid()
# Out:
# 0

# %%
os.path('/tmp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-90483f52b573> in <module>()
# ----> 1 os.path('/tmp')
#
# TypeError: 'module' object is not callable

# %%
import os

# %%
os.path('/tmp/123')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-bdde800068d7> in <module>()
# ----> 1 os.path('/tmp/123')
#
# TypeError: 'module' object is not callable

# %%
help(os.path)
# Out:
# Help on module posixpath:
#
# NAME
#     posixpath - Common operations on Posix pathnames.
#
# MODULE REFERENCE
#     https://docs.python.org/3.5/library/posixpath.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Instead of importing this module directly, import os and refer to
#     this module as os.path.  The "os.path" name is an alias for this
#     module on Posix systems; on other systems (e.g. Mac, Windows),
#     os.path provides the same operations in a manner specific to that
#     platform, and is an alias to another module (e.g. macpath, ntpath).
#
#     Some of this can actually be useful on non-Posix systems too, e.g.
#     for manipulation of the pathname component of URLs.
#
# FUNCTIONS
#     abspath(path)
#         Return an absolute path.
#
#     basename(p)
#         Returns the final component of a pathname
#
#     commonpath(paths)
#         Given a sequence of path names, returns the longest common sub-path.
#
#     commonprefix(m)
#         Given a list of pathnames, returns the longest common leading component
#
#     dirname(p)
#         Returns the directory component of a pathname
#
#     exists(path)
#         Test whether a path exists.  Returns False for broken symbolic links
#
#     expanduser(path)
#         Expand ~ and ~user constructions.  If user or $HOME is unknown,
#         do nothing.
#
#     expandvars(path)
#         Expand shell variables of form $var and ${var}.  Unknown variables
#         are left unchanged.
#
#     getatime(filename)
#         Return the last access time of a file, reported by os.stat().
#
#     getctime(filename)
#         Return the metadata change time of a file, reported by os.stat().
#
#     getmtime(filename)
#         Return the last modification time of a file, reported by os.stat().
#
#     getsize(filename)
#         Return the size of a file, reported by os.stat().
#
#     isabs(s)
#         Test whether a path is absolute
#
#     isdir(s)
#         Return true if the pathname refers to an existing directory.
#
#     isfile(path)
#         Test whether a path is a regular file
#
#     islink(path)
#         Test whether a path is a symbolic link
#
#     ismount(path)
#         Test whether a path is a mount point
#
#     join(a, *p)
#         Join two or more pathname components, inserting '/' as needed.
#         If any component is an absolute path, all previous path components
#         will be discarded.  An empty last part will result in a path that
#         ends with a separator.
#
#     lexists(path)
#         Test whether a path exists.  Returns True for broken symbolic links
#
#     normcase(s)
#         Normalize case of pathname.  Has no effect under Posix
#
#     normpath(path)
#         Normalize path, eliminating double slashes, etc.
#
#     realpath(filename)
#         Return the canonical path of the specified filename, eliminating any
#         symbolic links encountered in the path.
#
#     relpath(path, start=None)
#         Return a relative version of a path
#
#     samefile(f1, f2)
#         Test whether two pathnames reference the same actual file
#
#     sameopenfile(fp1, fp2)
#         Test whether two open file objects reference the same file
#
#     samestat(s1, s2)
#         Test whether two stat buffers reference the same file
#
#     split(p)
#         Split a pathname.  Returns tuple "(head, tail)" where "tail" is
#         everything after the final slash.  Either part may be empty.
#
#     splitdrive(p)
#         Split a pathname into drive and path. On Posix, drive is always
#         empty.
#
#     splitext(p)
#         Split the extension from a pathname.
#
#         Extension is everything from the last dot to the end, ignoring
#         leading dots.  Returns "(root, ext)"; ext may be empty.
#
# DATA
#     __all__ = ['normcase', 'isabs', 'join', 'splitdrive', 'split', 'splite...
#     altsep = None
#     curdir = '.'
#     defpath = ':/bin:/usr/bin'
#     devnull = '/dev/null'
#     extsep = '.'
#     pardir = '..'
#     pathsep = ':'
#     sep = '/'
#     supports_unicode_filenames = False
#
# FILE
#     /root/.pyenv/versions/3.5.2/lib/python3.5/posixpath.py

# %%
os.path.basename('/tmp')
# Out:
# 'tmp'

# %%
os.path.dirname('/tmp')
# Out:
# '/'

# %%
shutil.move('/tmp/123/','/tmp/567')
# Out:
# '/tmp/567'

# %%
ls /tmp
# Out:
# 567/  d/
# a/    systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE/
# b/    systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4/
# c/    test/

# %%
shutil.copytree('/tmp/567','/tmp/789')
# Out:
# '/tmp/789'

# %%
ls /tmp
# Out:
# 567/  d/
# 789/  systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE/
# a/    systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4/
# b/    test/
# c/

# %%
os.listdir('/tmp')
# Out:
# ['.ICE-unix',
#  '.XIM-unix',
#  '.font-unix',
#  '.X11-unix',
#  '.Test-unix',
#  'test',
#  'a',
#  'b',
#  'c',
#  'd',
#  'systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4',
#  'systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE',
#  '567',
#  '789']

# %%
os.walk('/tmp/')
# Out:
# <generator object walk at 0x7f678c36c678>

# %%
for r,d,f in os.walk('/tmp'):
    print(r)
    print(d)
    print(f)
    print('-------')
# Out:
# /tmp
# ['.ICE-unix', '.XIM-unix', '.font-unix', '.X11-unix', '.Test-unix', 'test', 'a', 'b', 'c', 'd', 'systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4', 'systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE', '567', '789']
# []
# -------
# /tmp/.ICE-unix
# []
# []
# -------
# /tmp/.XIM-unix
# []
# []
# -------
# /tmp/.font-unix
# []
# []
# -------
# /tmp/.X11-unix
# []
# []
# -------
# /tmp/.Test-unix
# []
# []
# -------
# /tmp/test
# ['test100']
# []
# -------
# /tmp/test/test100
# ['a', 'b']
# []
# -------
# /tmp/test/test100/a
# []
# ['test']
# -------
# /tmp/test/test100/b
# []
# ['test']
# -------
# /tmp/a
# []
# ['file', 'file1']
# -------
# /tmp/b
# []
# ['file']
# -------
# /tmp/c
# []
# ['file', 'file1']
# -------
# /tmp/d
# ['a']
# ['file', 'file1', 'hello.py']
# -------
# /tmp/d/a
# []
# ['file', 'file1']
# -------
# /tmp/systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4
# ['tmp']
# []
# -------
# /tmp/systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4/tmp
# ['vmware-root']
# []
# -------
# /tmp/systemd-private-336b0770623344eeb637db073fac974c-vmtoolsd.service-oVVoD4/tmp/vmware-root
# []
# []
# -------
# /tmp/systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE
# ['tmp']
# []
# -------
# /tmp/systemd-private-336b0770623344eeb637db073fac974c-cups.service-VSP0sE/tmp
# []
# []
# -------
# /tmp/567
# []
# []
# -------
# /tmp/789
# []
# []
# -------

# %%
ls /tmp/d/a
# Out:
# file  file1@

# %%
os.scandir('/tmp')

# %%
it = os.scandir('/tmp')

# %%
next(it)
# Out:
# <DirEntry '.ICE-unix'>

# %%
next(it)
# Out:
# <DirEntry '.XIM-unix'>

# %%
next(it)
# Out:
# <DirEntry '.font-unix'>

# %%
entity = next(it)

# %%
entity.path
# Out:
# '/tmp/.X11-unix'

# %%
entity.path
# Out:
# '/tmp/.X11-unix'

# %%
entity.path
# Out:
# '/tmp/.X11-unix'

# %%
entity.name
# Out:
# '.X11-unix'

# %%
os.path.basename('/tmp')
# Out:
# 'tmp'

# %%
os.path.dirname('/tmp')
# Out:
# '/'

# %%
os.path.join('tm','d','a')
# Out:
# 'tm/d/a'

# %%
os.path.split('/tmp')
# Out:
# ('/', 'tmp')

# %%
os.path.abspath('567')
# Out:
# '/root/py3.5.2/python3.5.2/notes/6/567'

# %%
import sys

# %%
sys.path
# Out:
# ['',
#  '/root/.pyenv/versions/3.5.2/lib/python35.zip',
#  '/root/.pyenv/versions/3.5.2/lib/python3.5',
#  '/root/.pyenv/versions/3.5.2/lib/python3.5/plat-linux',
#  '/root/.pyenv/versions/3.5.2/lib/python3.5/lib-dynload',
#  '/root/.pyenv/versions/3.5.2/envs/python/lib/python3.5/site-packages',
#  '/root/.pyenv/versions/3.5.2/envs/python/lib/python3.5/site-packages/IPython/extensions',
#  '/root/.ipython']

# %%
sys.argv
# Out:
# ['/root/.pyenv/versions/3.5.2/envs/python/lib/python3.5/site-packages/ipykernel/__main__.py',
#  '-f',
#  '/run/user/0/jupyter/kernel-5f4c3bb6-2642-426e-9e8c-4b735d89d541.json']

# %%
sys.argv[0]
# Out:
# '/root/.pyenv/versions/3.5.2/envs/python/lib/python3.5/site-packages/ipykernel/__main__.py'

# %%
os.getcwd()
# Out:
# '/root/py3.5.2/python3.5.2/notes/6'

# %%
os.path.split('/tmp')
# Out:
# ('/', 'tmp')

# %%
os.path.splitext('tar.t.c')
# Out:
# ('tar.t', '.c')

# %%
import pickle

# %%
pickle.dumps(1)
# Out:
# b'\x80\x03K\x01.'

# %%
pickle.loads(b'\x80\x03K\x01.')
# Out:
# 1

# %%
pickle.loads(b'\x80\x03]q\x00(K\x01K\x02K\x03e.')
# Out:
# [1, 2, 3]

# %%
pickle.dump('123',qaz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-e234c973a52c> in <module>()
# ----> 1 pickle.dump('123',qaz)
#
# NameError: name 'qaz' is not defined

# %%
import io

# %%
fp = io.BytesIO()

# %%
pickle.dump(123,fp)

# %%
fp.tell()
# Out:
# 5

# %%
fp.read()
# Out:
# b''

# %%
fp.seek(0)
# Out:
# 0

# %%
fp.read()
# Out:
# b'\x80\x03K{.'

# %%
b =  pickle.dumps(123)

# %%
b
# Out:
# b'\x80\x03K{.'

# %%
b == fp.read()
# Out:
# False

# %%
fp.seek(0)
# Out:
# 0

# %%
b == fp.read()
# Out:
# True

# %% [markdown]
# c = pickle.load(fp)

# %%
fp.seek(0)
# Out:
# 0

# %%
c = pickle.load(fp)

# %%
c
# Out:
# 123

# %%
b
# Out:
# b'\x80\x03K{.'

# %%
pickle.loads(b'\x80\x03K{.')
# Out:
# 123

# %%
c == pickle.loads(b'\x80\x03K{.')
# Out:
# True

# %%
import json

# %%
json.dumps('123')
# Out:
# '"123"'

# %%
json.dumps(123)
# Out:
# '123'

# %%
json.loads("123")
# Out:
# 123

# %%
json.loads("123")
# Out:
# 123

# %%
help(json.load)
# Out:
# Help on function load in module json:
#
# load(fp, cls=None, object_hook=None, parse_float=None, parse_int=None, parse_constant=None, object_pairs_hook=None, **kw)
#     Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     a JSON document) to a Python object.
#
#     ``object_hook`` is an optional function that will be called with the
#     result of any object literal decode (a ``dict``). The return value of
#     ``object_hook`` will be used instead of the ``dict``. This feature
#     can be used to implement custom decoders (e.g. JSON-RPC class hinting).
#
#     ``object_pairs_hook`` is an optional function that will be called with the
#     result of any object literal decoded with an ordered list of pairs.  The
#     return value of ``object_pairs_hook`` will be used instead of the ``dict``.
#     This feature can be used to implement custom decoders that rely on the
#     order that the key and value pairs are decoded (for example,
#     collections.OrderedDict will remember the order of insertion). If
#     ``object_hook`` is also defined, the ``object_pairs_hook`` takes priority.
#
#     To use a custom ``JSONDecoder`` subclass, specify it with the ``cls``
#     kwarg; otherwise ``JSONDecoder`` is used.

# %%
json.dumps('abc')
# Out:
# '"abc"'

# %%
json.loads('"abc"')
# Out:
# 'abc'

# %%
fp

# %%
fp.seek(0)
# Out:
# 0

# %%
json.load(fp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-0064dabedb17> in <module>()
# ----> 1 json.load(fp)
#
# /root/.pyenv/versions/3.5.2/lib/python3.5/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     266         cls=cls, object_hook=object_hook,
#     267         parse_float=parse_float, parse_int=parse_int,
# --> 268         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     269
#     270
#
# /root/.pyenv/versions/3.5.2/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     310     if not isinstance(s, str):
#     311         raise TypeError('the JSON object must be str, not {!r}'.format(
# --> 312                             s.__class__.__name__))
#     313     if s.startswith(u'\ufeff'):
#     314         raise JSONDecodeError("Unexpected UTF-8 BOM (decode using utf-8-sig)",
#
# TypeError: the JSON object must be str, not 'bytes'

# %%
ff = io.StringIO()

# %%
json.dump("123abc",ff)

# %%
ff.tell()
# Out:
# 8

# %%
ff.seek(0)
# Out:
# 0

# %%
type(json.dumps("123abc"))
# Out:
# str

# %%
ff.read()
# Out:
# '"123abc"'

# %%
ff.seek(0)
# Out:
# 0

# %%
json.load(ff)
# Out:
# '123abc'

# %%
open('111')
# Out:
# <_io.TextIOWrapper name='111' mode='r' encoding='UTF-8'>

# %%
f = open('111')

# %%
f.read()
# Out:
# '123'

# %%
f.close()

# %%
f = open('./111','w')

# %%
ls ./111
# Out:
# ./111

# %%
cat ./111

# %%
f.write('hello')
# Out:
# 5

# %%
cat ./111

# %%
f.close()

# %%
cat ./111
# Out:
# hello

# %%
# %cat ./111
# Out:
# hello

# %%
f = open('./111',mode='x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-13-63cba2b456f9> in <module>()
# ----> 1 f = open('./111',mode='x')
#
# FileExistsError: [Errno 17] File exists: './111'

# %%
f = open('./111',mode='a')

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-15-bacd0e0f09a3> in <module>()
# ----> 1 f.read()
#
# UnsupportedOperation: not readable

# %%
f.write('xixi \n haha')
# Out:
# 11

# %%
f.close()

# %%
cat 111
# Out:
# helloxixi
#  haha

# %%
f = open('./111',mode='rb')

# %%
f.read()
# Out:
# b'helloxixi \n haha'

# %%
f.read()
# Out:
# b''

# %%
f.read()
# Out:
# b''

# %%
type(f.read())
# Out:
# bytes

# %%
f.close()

# %%
f.closed
# Out:
# True

# %%
f = open('two.py',mode='rb')   ## rb

# %%
f.tell()
# Out:
# 0

# %%
f.seek(3)
# Out:
# 3

# %%
f.read()
# Out:
# b'\xe4\xba\x8c\xe4\xb8\x89\xe5\x9b\x9b\xe4\xba\x94'

# %%
f.seek(3)        ## 回到第3个位置    按字节操作
# Out:
# 3

# %%
f.read().decode()     ## 一这个汉字没了
# Out:
# '二三四五'

# %%
f.seek(3)
# Out:
# 3

# %%
f.seek(3,1)          ## 在当前位置移动 3       'b'的就可以移动，'t'模式的就不可以移动
# Out:
# 6

# %%
f.read().decode()     ##  whence=current(1) 时，offset可以是任意整数
# Out:
# '三四五'

# %%
f.seek(3,2)         ##  从结束的位置往前移动 3 个字节
# Out:
# 18

# %%
f.read().decode()    ## 为什么读出来是空的呢？ 因为 3 是正数，是往后移动的
# Out:
# ''

# %%
f.seek(-3,2)
# Out:
# 12

# %%
f.read().decode()     ## 所以 whence=end(2)时，offset可以是任意整数
# Out:
# '五'

# %%
f.seek(100)      ## seek到不存在的位置       向后超出范围允许
# Out:
# 100

# %%
f.tell()
# Out:
# 100

# %%
f.seek(-1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-42-aa3c36d69d3e> in <module>()
# ----> 1 f.seek(-1)
#
# OSError: [Errno 22] Invalid argument

# %%
f.seek(-100,2)        ## 向前超出范围不允许
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-43-142c347793f0> in <module>()
# ----> 1 f.seek(-100,2)
#
# OSError: [Errno 22] Invalid argument

# %%
f.close()

# %% [markdown]
# mode=b
# * 按字节移动文件指针
# * 当whence为start(0)(默认值)，offset可以是任意整数
# * 当whence为current(1)或者end(2)，offset也可以是任意整数

# %%
cat two.py
# Out:
# 一二三四五

# %% [markdown]
# tell总是以字节来计算

# %%
ls
# Out:
# 111       hello               passwd     Untitled1.ipynb  x2.txt   xxx.txt
# gbk.txt   IO与文件操作.ipynb  test1.exe  Untitled.ipynb   x3.txt
# haha.txt  one.py              two.py     utf8.txt         xin.py*

# %%
f = open('./111')

# %%
f
# Out:
# <_io.TextIOWrapper name='./111' mode='r' encoding='UTF-8'>

# %%
f.read()
# Out:
# 'helloxixi \n haha'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'helloxixi \n haha'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read().split()
# Out:
# ['helloxixi', 'haha']

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read(3)
# Out:
# 'hel'

# %%
f.read(-1)
# Out:
# 'loxixi \n haha'

# %%
f.tell()
# Out:
# 16

# %%
f.close()

# %%
f = open('./111','rb')

# %%
f.read()
# Out:
# b'helloxixi \n haha'

# %%
f.seek(0)
# Out:
# 0

# %%
f.read(2)
# Out:
# b'he'

# %%
f.seek(2,1)
# Out:
# 4

# %%
f.tell()
# Out:
# 4

# %%
f.read(1)
# Out:
# b'o'

# %%
cat 111
# Out:
# helloxixi
#  haha

# %%
f.writable()
# Out:
# False

# %%
f.read()
# Out:
# b'xixi \n haha'

# %%
f.readable()
# Out:
# True

# %%
f.seekable()
# Out:
# True

# %%
f.close()

# %%
f = open('one.py','r+t')

# %%
f.readable()
# Out:
# True

# %%
f.writable()
# Out:
# True

# %%
cat one.py
# Out:
# he�五六haha

# %%
f.write('12345')
# Out:
# 5

# %%
f.flush()

# %%
cat one.py
# Out:
# 12345�六haha

# %%
f.tell()
# Out:
# 5

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-86-bacd0e0f09a3> in <module>()
# ----> 1 f.read()
#
# /root/.pyenv/versions/3.5.2/lib/python3.5/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x94 in position 0: invalid start byte

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-88-bacd0e0f09a3> in <module>()
# ----> 1 f.read()
#
# /root/.pyenv/versions/3.5.2/lib/python3.5/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x94 in position 5: invalid start byte

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-91-bacd0e0f09a3> in <module>()
# ----> 1 f.read()
#
# /root/.pyenv/versions/3.5.2/lib/python3.5/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x94 in position 5: invalid start byte

# %%
f.readable()
# Out:
# True

# %%
f = open('one.py','a+')

# %%
cat one.py
# Out:
# 111lo,world!abc

# %%
f.tell()
# Out:
# 15

# %%
f.write('\n haha \n')
# Out:
# 8

# %%
f.flush()

# %%
cat one.py
# Out:
# 111lo,world!abc
#  haha

# %%
f.tell()
# Out:
# 23

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('nihao \n')
# Out:
# 7

# %%
f.flush()

# %%
cat one.py
# Out:
# 111lo,world!abc
#  haha
# nihao

# %%
f.tell()
# Out:
# 30

# %%
help(f.readline)
# Out:
# Help on built-in function readline:
#
# readline(size=-1, /) method of _io.TextIOWrapper instance
#     Read until newline or EOF.
#
#     Returns an empty string if EOF is hit immediately.

# %%
help(f.readlines)
# Out:
# Help on built-in function readlines:
#
# readlines(hint=-1, /) method of _io.TextIOWrapper instance
#     Return a list of lines from the stream.
#
#     hint can be specified to control the number of lines read: no more
#     lines will be read if the total size (in bytes/characters) of all
#     lines so far exceeds hint.

# %%
f.tell()
# Out:
# 30

# %%
f.readlines()
# Out:
# ['111lo,world!abc\n', ' haha \n', 'nihao \n']

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# '111lo,world!abc\n'

# %%
f.seek(0)
# Out:
# 0

# %%
for i in f.readlines():
    print(i.strip())
# Out:
# 111lo,world!abc
# haha
# nihao

# %%
f.close()

# %%
f = open('one.py','w')

# %%
f.name
# Out:
# 'one.py'

# %%
f.encoding
# Out:
# 'UTF-8'

# %%
f.errors
# Out:
# 'strict'

# %%
f.write('123')
# Out:
# 3

# %%
f.seek(0)
# Out:
# 0

# %%
f.write('abc \n')
# Out:
# 5

# %%
f.close()

# %%
cat one.py
# Out:
# 123abc

# %%
f.writelines(['abcd','\n','123'])

# %%
f.close()

# %%
cat one.py
# Out:
# abcd
# 123

# %%
with open('one.py','w') as f:
    f.writelines(['abc','\n','123'])

# %%
f.closed
# Out:
# True

# %%
cat one.py
# Out:
# abc
# 123

# %%
f.readlines()
# Out:
# ['111lo,world!abc\n', ' haha \n', 'nihao \n']

# %%
f.read()
# Out:
# 'hello,world!'

# %%
f.seek(0)
# Out:
# 0

# %%
f.tell()
# Out:
# 0

# %%
f.write('111')
# Out:
# 3

# %%
f.flush()

# %%
cat one.py
# Out:
# 111lo,world!

# %%
f.tell()
# Out:
# 3

# %%
f.read()
# Out:
# 'lo,world!'

# %%
f.tell()
# Out:
# 12

# %%
f.write('abc')
# Out:
# 3

# %%
f.flush()

# %%
cat one.py
# Out:
# 111lo,world!abc

# %%
f.read().encode()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-99-a16e67c8c1cd> in <module>()
# ----> 1 f.read().encode()
#
# /root/.pyenv/versions/3.5.2/lib/python3.5/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x94 in position 5: invalid start byte

# %%
f.seek(0)
# Out:
# 0

# %%
cat one.py
# Out:
# 12345�六haha

# %%
f.close()

# %%
f=open('one.py','w')

# %%
f.write('hello,world!')
# Out:
# 12

# %%
f.close()

# %%
ls
# Out:
# 222  888       hello               passwd     Untitled1.ipynb  x3.txt
# 333  aa/       IO与文件操作.ipynb  test1.exe  Untitled.ipynb   xin.py*
# 555  gbk.txt   mm/                 tt/        utf8.txt         xxx.txt
# 666  haha.txt  one.py              two.py     x2.txt

# %%
import pickle

# %%
pickle.dumps('abc')
# Out:
# b'\x80\x03X\x03\x00\x00\x00abcq\x00.'

# %%
pickle.loads(b'\x80\x03X\x03\x00\x00\x00abcq\x00.')
# Out:
# 'abc'

# %%
pickle.dump('abc',fd)

# %%
fd.close()

# %%
cat 222
# Out:
# �Xabcdefq.�Xabcq.

# %%
type(222)
# Out:
# int

# %%
xd = open('222','rb')

# %%
type(xd)
# Out:
# _io.TextIOWrapper

# %%
type(xd.read())
# Out:
# bytes

# %%
xd.close()

# %%
cat 222
# Out:
# �Xabcdefq.�Xabcq.

# %%
xd = open('222','rb')

# %%
pickle.load(xd)
# Out:
# 'abcdef'

# %%
xd.close()

# %%
import json

# %%
json.dumps('abcdefg')
# Out:
# '"abcdefg"'

# %%
json.loads('"abcdef"')
# Out:
# 'abcdef'

# %%
json.dumps('[1,2,3]')
# Out:
# '"[1,2,3]"'

# %%
json.loads('"(1,2,3)"')
# Out:
# '(1,2,3)'

# %%
json.loads('"abc"')
# Out:
# 'abc'

# %%
fff = open('./222','w')

# %%
json.dump('abc123',fff)

# %%
fff.close()

# %%
cat 222
# Out:
# "abc123"

# %%
xxx = open('222')

# %%
json.load(xxx)
# Out:
# 'abc123'

# %%
fd = open('222','ab+')

# %%
ls
# Out:
# 222  888       hello               passwd     Untitled1.ipynb  x3.txt
# 333  aa/       IO与文件操作.ipynb  test1.exe  Untitled.ipynb   xin.py*
# 555  gbk.txt   mm/                 tt/        utf8.txt         xxx.txt
# 666  haha.txt  one.py              two.py     x2.txt

# %%
cat 888
# Out:
# abc

# %%
t = open('xin.py','r')

# %%
next(t)
# Out:
# 'while True:\n'

# %%
next(t)
# Out:
# '#_*_ coding:utf-8 _*_\n'

# %%
t.close()

# %%
def a(path):
    with open(path) as f :
        for i in f:
            yield i

# %%
a('888')
# Out:
# <generator object a at 0x7f5ad1cf2f10>

# %%
for i in a('xin.py'):
    print (i)
# Out:
# #!/usr/bin/env python
#
# #_*_ coding:utf-8 _*_
#
# import os
#
# while True:
#
# 	print '''		 \033**************************************\033
#
# 		 \033*	1.Search		      *\033
#
# 		 \033*	2.Add、Del、Change	      *\033
#
# 		 \033**************************************\033'''
#
# 	action = int(raw_input('Please enter the number of your needs? '))
#
# 	if action == 1:
#
# 		count_number = 0
#
# 		Action_One_Key = raw_input('Please enter a keyword query: ')
#
# 		F = file('staff.txt','r')
#
# 		for line in F.readlines():
#
# 			if Action_One_Key in line:
#
# 				count_number += 1
#
# 				line_strip = line.strip()
#
# 				print '\033 %s\033' %line_strip
#
# 		print '\033count_number: %s\033' %count_number
#
# 		Goon_key = raw_input('Do you want to continue? (y|n) ')
#
# 		if Goon_key == 'n':
#
# 			break
#
# 	elif action == 2:
#
# 		print '''                 \033**************************************\033
#
#                  \033*    1.Add                           *\033
#
#                  \033*    2.Del                           *\033
#
# 		 \033*    3.Change                        *\033
#
#                  \033**************************************\033'''
#
# 		action_2 = int(raw_input('Please enter the number of your needs? '))
#
# 		if action_2 == 1:
#
# 			input_str = raw_input('Please enter the information you want to add employees: ')
#
# 			F_write = file('staff.txt','a')
#
# 			F_write.write('%s\n'%input_str)
#
# 			F_write.close()
#
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#
#                 	if Goon_key == 'n':
#
#                         	break
#
# 		elif action_2 == 2:
#
# 			del_str = raw_input('Please enter your user information to be deleted: ')
#
# 			F_del = file('staff.txt','r')
#
# 			F_del_new = file('staff_del_bak.txt','w')
#
# 			for line in F_del.readlines():
#
# 				if del_str in line:
#
# 					continue
#
# 				F_del_new.write(line)
#
# 			F_del.close()
#
# 			F_del_new.close()
#
# 			os.rename('staff_del_bak.txt','staff.txt')
#
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#
#                         if Goon_key == 'n':
#
#                                 break
#
# 		elif action_2 == 3:
#
# 			input_change_str = raw_input('Please enter your user information to be modified: ')
#
# 			input_change_str2 = raw_input('Please enter the modified content: ')
#
# 			F_change_source = file('staff.txt','r')
#
# 			F_change_new = file('staff_change_bak.txt','w')
#
# 			for line in  F_change_source.readlines():
#
# 				if input_change_str in line:
#
# 					line = line.replace(input_change_str,input_change_str2)
#
# 					print line
#
# 				F_change_new.write('%s\n'%line)
#
# 			F_change_source.close()
#
# 			F_change_new.close()
#
# 			os.rename('staff_change_bak.txt','staff.txt')
#
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#
#                         if Goon_key == 'n':
#
#                                 break
#
# 		else:
#
# 			print '\033非法序列！请输入正确的操作符号！\033'
#
# 	else:
#
# 		print '\033非法序列！请输入正确的操作符号！\033'

# %%
a('xin.py')
# Out:
# <generator object a at 0x7f5ad27b1f68>

# %%
def b(path):
    t = open(path,'r')
    for v in t:                ## 这两句可被   yield from t 来代替！
        yield v

# %%
b('xin.py')
# Out:
# <generator object b at 0x7f5ad1cf25c8>

# %%
for i in b('666'):
    print(i)
# Out:
# "abc"

# %%
for i in b('888'):
    print (i)
# Out:
# abc

# %%
help(yield)
# Out:
#   File "<ipython-input-28-19cdfd08e641>", line 1
#     help(yield)
#              ^
# SyntaxError: invalid syntax

# %%
help(yield)
# Out:
#   File "<ipython-input-29-19cdfd08e641>", line 1
#     help(yield)
#              ^
# SyntaxError: invalid syntax

# %%
xx = open('xin.py')

# %%
for i in xx:
    print(i)
# Out:
# #!/usr/bin/env python
#
# #_*_ coding:utf-8 _*_
#
# import os
#
# while True:
#
# 	print '''		 \033**************************************\033
#
# 		 \033*	1.Search		      *\033
#
# 		 \033*	2.Add、Del、Change	      *\033
#
# 		 \033**************************************\033'''
#
# 	action = int(raw_input('Please enter the number of your needs? '))
#
# 	if action == 1:
#
# 		count_number = 0
#
# 		Action_One_Key = raw_input('Please enter a keyword query: ')
#
# 		F = file('staff.txt','r')
#
# 		for line in F.readlines():
#
# 			if Action_One_Key in line:
#
# 				count_number += 1
#
# 				line_strip = line.strip()
#
# 				print '\033 %s\033' %line_strip
#
# 		print '\033count_number: %s\033' %count_number
#
# 		Goon_key = raw_input('Do you want to continue? (y|n) ')
#
# 		if Goon_key == 'n':
#
# 			break
#
# 	elif action == 2:
#
# 		print '''                 \033**************************************\033
#
#                  \033*    1.Add                           *\033
#
#                  \033*    2.Del                           *\033
#
# 		 \033*    3.Change                        *\033
#
#                  \033**************************************\033'''
#
# 		action_2 = int(raw_input('Please enter the number of your needs? '))
#
# 		if action_2 == 1:
#
# 			input_str = raw_input('Please enter the information you want to add employees: ')
#
# 			F_write = file('staff.txt','a')
#
# 			F_write.write('%s\n'%input_str)
#
# 			F_write.close()
#
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#
#                 	if Goon_key == 'n':
#
#                         	break
#
# 		elif action_2 == 2:
#
# 			del_str = raw_input('Please enter your user information to be deleted: ')
#
# 			F_del = file('staff.txt','r')
#
# 			F_del_new = file('staff_del_bak.txt','w')
#
# 			for line in F_del.readlines():
#
# 				if del_str in line:
#
# 					continue
#
# 				F_del_new.write(line)
#
# 			F_del.close()
#
# 			F_del_new.close()
#
# 			os.rename('staff_del_bak.txt','staff.txt')
#
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#
#                         if Goon_key == 'n':
#
#                                 break
#
# 		elif action_2 == 3:
#
# 			input_change_str = raw_input('Please enter your user information to be modified: ')
#
# 			input_change_str2 = raw_input('Please enter the modified content: ')
#
# 			F_change_source = file('staff.txt','r')
#
# 			F_change_new = file('staff_change_bak.txt','w')
#
# 			for line in  F_change_source.readlines():
#
# 				if input_change_str in line:
#
# 					line = line.replace(input_change_str,input_change_str2)
#
# 					print line
#
# 				F_change_new.write('%s\n'%line)
#
# 			F_change_source.close()
#
# 			F_change_new.close()
#
# 			os.rename('staff_change_bak.txt','staff.txt')
#
# 			Goon_key = raw_input('Do you want to continue? (y|n) ')
#
#                         if Goon_key == 'n':
#
#                                 break
#
# 		else:
#
# 			print '\033非法序列！请输入正确的操作符号！\033'
#
# 	else:
#
# 		print '\033非法序列！请输入正确的操作符号！\033'

# %%
t.closed
# Out:
# True

# %%
ip = {'a':'b','c':2}

# %%
type(ip)
# Out:
# dict

# %%
ip
# Out:
# {'a': 'b', 'c': 2}

# %%
print(ip.keys())
# Out:
# dict_keys(['a', 'c'])

# %%
for i in ip.keys():
    print (i)
# Out:
# a
# c

# %%
a in ip.keys()
# Out:
# False

# %%
'a'  in ip.keys()
# Out:
# True

# %%
ls /tmp
# Out:
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW/
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp/

# %%
import os

# %%
os.mkdir('/tmp/abc')

# %%
ls /tmp
# Out:
# abc/
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW/
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp/

# %%
import shutil

# %%
shutil.move('/tmp/abc','/tmp/123')
# Out:
# '/tmp/123'

# %%
ls /tmp/
# Out:
# 123/
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW/
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp/

# %%
shutil.copytree('/tmp/123/','/root/999')
# Out:
# '/root/999'

# %%
ls /root/999/

# %%
shutil.rmtree('/root/999/')

# %%
ls /root/
# Out:
# ????????2.ipynb              li/                                test.py*
# access.log-20160811          lili.py                            ttttttt
# anaconda-ks.cfg              mxdx2.ipynb                        :wq
# backup-script/               py3.5.2/                           xin.py*
# chen/                        pycharm-community-2016.2.2/        zip.zip
# docker/                      pycharm-community-2016.2.2.tar.gz  公共/
# epel-release-7-6.noarch.rpm  PycharmProjects/                   模板/
# eth.sh*                      python/                            视频/
# git/                         root/                              图片/
# haha                         staff.txt                          文档/
# hahaxixi                     tar.py                             下载/
# hello/                       test/                              音乐/
# initial-setup-ks.cfg         test3.py*                          桌面/

# %%
os.listdir('/tmp')
# Out:
# ['.ICE-unix',
#  '.XIM-unix',
#  '.font-unix',
#  '.X11-unix',
#  '.Test-unix',
#  'systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp',
#  'systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW',
#  '123']

# %%
for a,b,c in os.walk('/tmp'):
    print(a)
    print(b)
    print(c)
# Out:
# /tmp
# ['.ICE-unix', '.XIM-unix', '.font-unix', '.X11-unix', '.Test-unix', 'systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp', 'systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW', '123']
# []
# /tmp/.ICE-unix
# []
# []
# /tmp/.XIM-unix
# []
# []
# /tmp/.font-unix
# []
# []
# /tmp/.X11-unix
# []
# []
# /tmp/.Test-unix
# []
# []
# /tmp/systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp
# ['tmp']
# []
# /tmp/systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp/tmp
# ['vmware-root']
# []
# /tmp/systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp/tmp/vmware-root
# []
# []
# /tmp/systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW
# ['tmp']
# []
# /tmp/systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW/tmp
# []
# []
# /tmp/123
# []
# []

# %%
ls /tmp
# Out:
# 123/
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-cups.service-6aMakW/
# systemd-private-0b21322a4ade43dcb11cc70e10a80aaa-vmtoolsd.service-0aaoAp/

# %%
os.path.dirname('1/2/3/4/5')
# Out:
# '1/2/3/4'

# %%
os.getcwd()
# Out:
# '/root/py3.5.2/python3.5.2/notes/6'

# %%
import pickle

# %%
pickle.dumps(123)
# Out:
# b'\x80\x03K{.'

# %%
pickle.loads(b'\x80\x03K{.')
# Out:
# 123

# %%
f = open('ha6.txt','wb')

# %%
a
# Out:
# 'abc'

# %%
f.close()

# %%
cat ha6.txt
# Out:
# �Xabcq.

# %%
c = open('ha6.txt','rb')

# %%
c.read()
# Out:
# b'\x80\x03X\x03\x00\x00\x00abcq\x00.'

# %%
b = pickle.dumps(a)

# %%
b
# Out:
# b'\x80\x03X\x03\x00\x00\x00abcq\x00.'

# %%
c.read()  == b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-710fa92f3984> in <module>()
# ----> 1 c.read()  == b
#
# ValueError: read of closed file

# %%
pickle.load(c)
# Out:
# 'abc'

# %%
c.close()

# %%
c.seek(0)
# Out:
# 0

# %%
c.close()

# %%
cat ha6.txt

# %%
a = 'abc'

# %%
pickle.dump(a,f)

# %%
import json

# %%
json.dumps('abc')
# Out:
# '"abc"'

# %%
json.loads('"abc"')
# Out:
# 'abc'

# %%
a = '陈'

# %%
a
# Out:
# '陈'

# %%
c = open('hx','w')

# %%
json.dump(a,c)

# %%
cat hx

# %%
c.close()

# %%
cat hx
# Out:
# "\u9648"

# %%
json.loads('"\u9648"')
# Out:
# '陈'

# %%
f = open('hx')

# %%
json.load(f)
# Out:
# '陈'

# %%
f.close()
