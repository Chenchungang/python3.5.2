# %%
open('/root/haha','a')          ## 终于设置出了root也没有权限的！   
                           ## 用了这个命令[root@python3 ~]# chattr +i haha ，就不能写啦
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-4623b0a52bfd> in <module>()
# ----> 1 open('/root/haha','a')
#
# PermissionError: [Errno 13] Permission denied: '/root/haha'

# %%
try:    ## 尝试做这件事
    open('/root/haha','a')
except:                        ## 如果不成功的时候        把它记录下来了
    print('write error /root/haha')
# Out:
# write error /root/haha

# %%
if 'a' if     ## 显然，这是一个错误
# Out:
#   File "<ipython-input-9-6bd2ead52ee4>", line 1
#     if 'a' if
#               ^
# SyntaxError: invalid syntax

# %%
try:
    if 'a' if
except: 
    print('ha ha ha')           ## 这样就不行，这种叫错误
# Out:
#   File "<ipython-input-10-2057debac636>", line 2
#     if 'a' if
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# 异常可以被处理，错误不可处理

# %% [markdown]
# 错误，解释器肯定退出了，不可处理

# %%
语法错误、缩进错误、解释器内部错误   这些通常是最常见的错误

# %%
我们所出现的大多数，都是异常

# %% [markdown]
# 怎么处理异常？  try  except 语句

# %%
try:
    ## 可能抛出异常的语句，  会一直执行，直到抛出异常
except:
    ## 异常处理语句   当try块任意语句抛出异常时执行

# %%
try:
    print(1+1)
    print('--------')
except:
    print('except')
# Out:
# 2
# --------

# %%
try:
    print(1+1)
    print('--------')
    print(1/0)            ## 抛出异常了
except:
    print('except')
# Out:
# 2
# --------
# except

# %%
try:
    print(1+1)
    print('--------')
    print(1/0)            ## 抛出异常了     当抛出时，就中断了语句执行，然后到except块中
    print('********')
except:
    print('except')
# Out:
# 2
# --------
# except

# %%
try:
    a = 5
    1 / 0          ## 触发一个错误 
except:           ## try 里定义的变量，except中可以使用
    print(a)
# Out:
# 5

# %%
try:   
    open('/root/haha','a')
except Exception as e :             ## e表示Exception的一个实例 表示只关注Exception的这种异常                        
    print('write error /root/haha {}'.format(e))
# Out:
# write error /root/haha [Errno 13] Permission denied: '/root/haha'

# %%
try:   
    open('/root/haha','a')
except TypeError as e :     ## 指定的异常的捕获类型，只有异常属于这个类型，才会被捕获   这里因为异常不是这个，所以抛出了错误
    print('write error /root/haha {}'.format(e))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-16-c5d498280ba3> in <module>()
#       1 try:
# ----> 2     open('/root/haha','a')
#       3 except TypeError as e :
#       4     print('write error /root/haha {}'.format(e))
#
# PermissionError: [Errno 13] Permission denied: '/root/haha'

# %% [markdown]
# 对不同的异常做不同的处理

# %%
try:
    open('/root/haha','a')
except TypeError:           ## as e是可选的，as e是把错误赋值给e
    print('type error')
except PermissionError:
    print('Permission denied')
# Out:
# Permission denied

# %% [markdown]
# 通过指定类型对不同的异常做不同的处理

# %%
try:
    open('/root/haha','a')
except Exception:              ## 找到匹配项，就不会往下再匹配了
    print('error')
except PermissionError:
    print('Permission denied')
# Out:
# error

# %%
print(PermissionError.__bases__)        ## 它的父类是OSError
# Out:
# (<class 'OSError'>,)

# %%
help(PermissionError)        ## 它是继承自OSError
# Out:
# Help on class PermissionError in module builtins:
#
# class PermissionError(OSError)
#  |  Not enough permissions.
#  |
#  |  Method resolution order:
#  |      PermissionError
#  |      OSError
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from OSError:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from OSError:
#  |
#  |  characters_written
#  |
#  |  errno
#  |      POSIX exception code
#  |
#  |  filename
#  |      exception filename
#  |
#  |  filename2
#  |      second exception filename
#  |
#  |  strerror
#  |      exception strerror
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
OSError.__bases__
# Out:
# (Exception,)

# %%
所以,PermissionError错误的实例，都属于Exception的实例  ## 找到匹配项，就不会往下再匹配了

# %% [markdown]
# 当有多个except时，从上往下，匹配到第一条就停止匹配

# %% [markdown]
# 通常会把具体的异常放到上面，一般性的异常放到下面

# %%
PermissionError(它就更具体) OSError(它就更一般性)  Exception(它就更更一般性)  
## 具体跟一般都是相对来说的
## 通常来说，子类更具体，父类更一般性

# %% [markdown]
# 所以，以下通常要这么写

# %%
try:
    open('/root/haha','a')
except PermissionError:
    print('Permission denied')
except Exception:             
    print('error')
# Out:
# Permission denied

# %%
try:
    open('/root/haha','a')
except PermissionError:
    print('Permission denied')
except Exception:             
    print('error')
except:
    print('....')
# Out:
# Permission denied

# %%
def gen():
    yield 1

# %%
g = gen()

# %%
next(g)
# Out:
# 1

# %%
try:
    ## open('/root/haha','a')
    next(g)                  ##  这里正常的话，应该抛出一个StopIteration的异常
except PermissionError:     ## StopIteration 并不是PermissionError的子类，所以匹配到下面的
    print('Permission denied')
except Exception:             
    print('error')
except:
    print('....')
# Out:
# error

# %%
try:
    ## open('/root/haha','a')
    ## next(g)  
    raise KeyboardInterrupt()         ##  主动抛出一个异常
except PermissionError:    
    print('Permission denied')
except Exception:             
    print('error')
except:         ##  当不带任何模式的时候，相当于default分支，会捕获所有未捕获的异常
    print('....')
# Out:
# ....

# %%
help(Exception)        ## 继承于BaseException
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
help(BaseException)    ## 继承自object
# Out:
# Help on class BaseException in module builtins:
#
# class BaseException(object)
#  |  Common base class for all exceptions
#  |
#  |  Methods defined here:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
* BaseException
  * Exception       ## 下面三个是非常特殊的异常  Exception是除以下三个之外所有异常的祖先
  * KeyboardInterrupt  -> 代表的是键盘中断事件，ctrl+c
  * SystemExit    -> 代表的是解释器退出
  * GeneratorExit  -> 代表生成器退出                 ## 可各自help看看

# %%
help(SystemExit)
# Out:
# Help on class SystemExit in module builtins:
#
# class SystemExit(BaseException)
#  |  Request to exit from the interpreter.
#  |
#  |  Method resolution order:
#  |      SystemExit
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  code
#  |      exception code
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __reduce__(...)
#  |      helper for pickle
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
except Exception == except    ## 这是一种错觉   事实上它们并不等价

# %% [markdown]
# 当然啦，标准库或第三方库还有很多的异常，无法完全得到完整的异常列表和层次；所以知道上面的就可以了

# %% [markdown]
# 还是用haha这个不可写的文件！

# %%
try:
    f = open('/root/haha','a')
    f.write('houhou\n')      ## 抛出异常
    f.close()        ## 这个语句就执行不到了
except:
    print('process haha error')
# Out:
# process haha error

# %%
try:
    f = open('/root/haha','a')   ## 这条就抛出异常了
    f.write('houhou\n')      ## 抛出异常
    ## f.close()        ## 这个语句就执行不到了
except:
    print('process haha error')
finally:
    print('close haha')
    f.close()
# Out:
# process haha error
# close haha

# %% [markdown]
# finally 语句总是会被执行，无论有没有抛出异常

# %%
try:
    f = open('/root/haha','a')
    ## f.write('houhou\n')      ## 抛出异常
    ## f.close()        ## 这个语句就执行不到了
except:
    print('process haha error')
finally:
    print('close haha')
    f.close()
# Out:
# process haha error
# close haha

# %%
try:
    f = open('/root/haha')            ## 这个正常的读打开不会报错
    ## f.write('houhou\n')      
    ## f.close()        
except:                              ## 所以这条不执行 
    print('process haha error')
finally:                             ## 但是finally一定会执行
    print('close haha')
    f.close()
# Out:
# close haha

# %%
f = None        

try:
    f = open('/root/haha')
    ## f.write('houhou\n')      
    ## f.close()        
except:
    print('process haha error')
finally:
    print('close haha')
    if f is not None:
        f.close()
# Out:
# close haha

# %%
f = None        

try:
    f = open('/root/haha','a')   ## 加上'a'，也会正常执行
    ## f.write('houhou\n')      
    ## f.close()        
except:
    print('process haha error')
finally:
    print('close haha')
    if f is not None:
        f.close()
# Out:
# process haha error
# close haha

# %% [markdown]
# finally 语句总是会被执行，无论有没有抛出异常，所以清理工作通常会放到finally语句块里执行！

# %%
f = None        
try:
    f = open('/root/haha')
    1 / 0  
except:
    print('process haha error')
finally:
    print('close haha')
    if f is not None:
        f.close()
# Out:
# process haha error
# close haha

# %%
def fn():
    try:
        print('try')
        return          
    finally:            ## finally可以没有except，只要有try就可以了
        print('finally')

# %%
fn()        ## 都return了，为什么还有后面的输出呢？？
# Out:
# try
# finally

# %%
def fn():
    x = 2
    def inner(x):
        print('inner')
        return x + 1
    try:
        print('try')
        return x         ##  已经确认了值
    finally:        
        x = inner(3)       ## finally这个时候再对 x 做修改已经没有用了

# %%
fn()      ## finally 在return 语句之后，但是在函数返回之前执行
# Out:
# try
# inner
# 2

# %%
def fn():
    x = [2]
    def inner(x):
        print('inner')
        return x + 1
    try:
        print('try')
        return x     ## 因为这里的 x 返回的是一个引用 ，所以下面finally再修改，是有用的！
    finally:        
        x[0] = inner(3)

# %%
fn()
# Out:
# try
# inner
# [4]

# %%
finally 在return 语句之后，但是在函数返回之前执行

# %%
def fn():
    def inner():
        print('inner')
    try:
        print('try')
        return inner()      
    finally:        
        print('finally')

# %%
fn()
# Out:
# try
# inner
# finally

# %%
import time
def fn():
    def inner():
        print('inner')
    try:
        print('try')
        return inner()      
    finally:     
        time.sleep(3)
        print('finally')

# %%
fn()        ## ok 等了3秒后才出现的finally
# Out:
# try
# inner
# finally

# %%
import time
def fn():
    def inner():
        print('inner')
        return 3
    try:
        print('try')
        return inner()      
    finally:     
        time.sleep(3)
        print('finally')

# %%
fn()   ## try 和inner一起执行的，等3秒后，finally和3一起输出的
# Out:
# try
# inner
# finally
# 3

# %%
import time
def fn():
    def inner():
        print('inner')
        return 3
    try:
        print('try')
        return inner()      
    finally:     
        print('finally')
        return 5

# %%
fn()        
## 最终为什么返回值是5呢？ 因为finally有最高优先级，它总是会被执行的
## 因为它return 了5，所以就会由它来结束函数
# Out:
# try
# inner
# finally
# 5

# %%
import time
def fn():
    def inner():
        print('inner')
        return 3
    try:
        print('try')
        return inner()      
    finally:     
        print('finally')
        return 5 
    return 6

# %%
fn()
# Out:
# try
# inner
# finally
# 5

# %%
import time
def fn():
    try:
        1 / 0
        return 3 
    except:
        return 4 
    finally:     
        return 5 
    return 6

# %%
fn()        ## 所以，记住规则，无论如何finally都会被执行到！
# Out:
# 5

# %%
def fn():
    try:
        1 / 0
        yield 3 
    except:
        yield 4 
    finally:     
        yield 5 
    yield 6

# %%
for x in fn():
    print(x)
# Out:
# 4
# 5
# 6

# %% [markdown]
# 所以就印证了  finally 在return 语句之后执行的，同样的它也在yield之后执行的

# %% [markdown]
# finally 在return 语句之后，但是在函数返回之前执行，通常来说，不在finally里retrun

# %% [markdown]
# 如果finally里有return的话，它一定会覆盖try跟except中的return，记住这个就好，所以通常来说，不会在finally里做retrun

# %%
class MyExcepetion(Exception):   ## 继承自 Exception或其子类  ## 这是自定义的异常
    pass

# %% [markdown]
# except 带有一个模式匹配的概念，它会匹配所抛出的异常，是否是此类型

# %% [markdown]
# 自定义异常需要我们自己来抛出

# %%
raise Exception()       ## raise 上升的意思
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-66-f6a4bc74e7ec> in <module>()
# ----> 1 raise Exception()
#
# Exception:

# %% [markdown]
# 可以使用raise抛出异常

# %% [markdown]
# raise后面跟一个异常的实例

# %%
class A:
    pass

# %%
raise A()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-29d2d3347840> in <module>()
# ----> 1 raise A()
#
# TypeError: exceptions must derive from BaseException

# %% [markdown]
# raise 后面只能跟一个异常的实例

# %%
def div(x,y):    ## 写一个除法
    return x / y

# %%
div(3,0)         ## 抛出了一个被0除的异常
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-70-f65daaf40671> in <module>()
# ----> 1 div(3,0)
#
# <ipython-input-69-3995b85f94cb> in div(x, y)
#       1 def div(x,y):    ## 写一个除法
# ----> 2     return x / y
#
# ZeroDivisionError: division by zero

# %%
class UserException(Exception):         ## 定义这个
    pass 

def div(x,y):   
    if y == 0 :
        raise UserException('y must not be zero')
    return x / y

# %%
div (3,0)      ## 抛出的异常是自定义的
# Out:
# ---------------------------------------------------------------------------
# UserException                             Traceback (most recent call last)
# <ipython-input-72-e99245ea19e0> in <module>()
# ----> 1 div (3,0)
#
# <ipython-input-71-987945148565> in div(x, y)
#       4 def div(x,y):
#       5     if y == 0 :
# ----> 6         raise UserException('y must not be zero')
#       7     return x / y
#
# UserException: y must not be zero

# %%
def div(x,y):
    try:
        return x / y
    except ZeroDivisionError:     ## 这种相对以上那个更面向对象一些，当输出这个时候，可以重新定义异常
        raise UserException('y must not be zero')  ## 捕获的是上面的异常，重新抛出这样的异常

# %%
div (3,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-73-d07672846181> in div(x, y)
#       2     try:
# ----> 3         return x / y
#       4     except ZeroDivisionError:     ## 这种更面向对象一些，当输出这个时候，可以重新定义异常
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# UserException                             Traceback (most recent call last)
# <ipython-input-74-e99245ea19e0> in <module>()
# ----> 1 div (3,0)
#
# <ipython-input-73-d07672846181> in div(x, y)
#       3         return x / y
#       4     except ZeroDivisionError:     ## 这种更面向对象一些，当输出这个时候，可以重新定义异常
# ----> 5         raise UserException('y must not be zero')
#
# UserException: y must not be zero

# %%
try:                     ## 这样，就可以有一个相对友好的提示由其给用户使用的时候
    div(3,0)
except UserException as e:
    print(e)
# Out:
# y must not be zero

# %%
try:                        ## 对不同种类型做不同的处理，这种方式用的非常多
    div(3,0)                ## 这也是自定义异常的用法 
except UserException as e:
    print(e)
except SystemExeption as e:
    pass
# Out:
# y must not be zero

# %%
class MyExcepetion(Exception):            
    def __init__(self,code,message):           ## 这些是自定义行为的  举例
        self.code = code                       ## 一般的只要不自定义的，只要pass就可以了
        self.message = message                 ## 只要让它继承自Exception就可以了
        super().__init__(message)
        
    def __str__(self):
        return '[{}]{}'.format(self.code,self.message)

# %%
SystemException = type('SystemException',(Exception,object),{})  ## python新手就看不懂啦

# %% [markdown]
# 不要用以上这个方式， 太装B了!

# %% [markdown]
# 注：自定义异常，写普通应用的时候，用的不是很多；但是写lib库的时候，或是写超大应用的时候，用的挺多

# %%
class UserException(Exception):  ## 自定义的时候，通常用这种方式，更中规中距一些
    pass 
class SystemException(Exception):
    pass 

def div(x,y):   
    if y == 0 :
        raise UserException('y must not be zero')
    return x / y

# %% [markdown]
# 什么时候需要异常处理？

# %%
def fn():
    raise Exception()

# %%
fn()       ## 解释器并不强制要求我们必须处理异常，如果我们不去看源码或者文档的时候，我们也并不知道此处会抛出一个异常
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-fd7064640434> in <module>()
# ----> 1 fn()
#
# <ipython-input-1-4b955ab8f9d7> in fn()
#       1 def fn():
# ----> 2     raise Exception()
#
# Exception:

# %% [markdown]
# 我们可以处理异常，也可以不处理

# %%
def fn2():
    print('fn2')
    fn()

# %%
fn2()
# Out:
# fn2
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-af5ceffc3832> in <module>()
# ----> 1 fn2()
#
# <ipython-input-3-2a83ae86f2d4> in fn2()
#       1 def fn2():
#       2     print('fn2')
# ----> 3     fn()
#
# <ipython-input-1-4b955ab8f9d7> in fn()
#       1 def fn():
# ----> 2     raise Exception()
#
# Exception:

# %% [markdown]
# 当我们不处理异常的时候，它会向上抛出

# %% [markdown]
# 异常的传递   异常总是向上层传递

# %% [markdown]
# 实际的编码过程中：我们应该在哪一层处理异常？

# %% [markdown]
# * 通常在endpoint处处理异常  ## endpoint 通常指的是一个边界
# * 有替代方案时，立即处理异常，使用替代方案
# * 异常作为业务逻辑   ** 极度不推荐**
# * 异常可以忽略
# * 异常需要延后处理，需要立刻处理，并暂存异常，以便延后处理

# %% [markdown]
# 通常使用以上第1种处理，但是有以上的其它4个例外

# %% [markdown]
# 这是老师自己的规则，经验之谈；不按这个做，也是OK的。

# %% [markdown]
# web 它的边界在哪里？  视图函数

# %%
## 通常这样来处理一个应用程序       这是web的边界

def view():
    try:
        ## call service 
    except A as a:       
        pass
    except B as b:
        pass
    except C as c:
        pass
    except:               ## default 的统一通用处理
        pass

# %% [markdown]
# 关注的/需要特殊处理的异常并不多

# %% [markdown]
# 多线程程序的边界在哪里？ target 函数

# %% [markdown]
# RPC的边界，service 方法

# %%
try:
    import MySQLdb 
except ImportError:
    import pymsql 
    
## 这种时候 就需要有替代方案时，立即处理异常，使用替代方案
