# %% [markdown]
# # 集合

# %%
特点：元素是唯一的
      元素是无序的

# %%
s = set()  ## 如果不给初始值的时候，可用set来定义

# %%
s = {1,2,3}   ## 有初始值的定义方式 可用大括号来定义

# %%
s ={} ## 但是不能这么定义集合  它虽然没有报错

# %%
type(s)   ## 是个字典，因为字典也是大括号定义的
# Out:
# dict

# %%
s
# Out:
# {}

# %%
s = {1,2,3}

# %%
s
# Out:
# {1, 2, 3}

# %%
type(s)
# Out:
# set

# %%
help(set)    ## 集合没有key
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __ixor__(self, value, /)
#  |      Return self^=value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(...)
#  |      S.__sizeof__() -> size of S in memory, in bytes
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  add(...)
#  |      Add an element to a set.
#  |
#  |      This has no effect if the element is already present.
#  |
#  |  clear(...)
#  |      Remove all elements from this set.
#  |
#  |  copy(...)
#  |      Return a shallow copy of a set.
#  |
#  |  difference(...)
#  |      Return the difference of two or more sets as a new set.
#  |
#  |      (i.e. all elements that are in this set but not the others.)
#  |
#  |  difference_update(...)
#  |      Remove all elements of another set from this set.
#  |
#  |  discard(...)
#  |      Remove an element from a set if it is a member.
#  |
#  |      If the element is not a member, do nothing.
#  |
#  |  intersection(...)
#  |      Return the intersection of two sets as a new set.
#  |
#  |      (i.e. all elements that are in both sets.)
#  |
#  |  intersection_update(...)
#  |      Update a set with the intersection of itself and another.
#  |
#  |  isdisjoint(...)
#  |      Return True if two sets have a null intersection.
#  |
#  |  issubset(...)
#  |      Report whether another set contains this set.
#  |
#  |  issuperset(...)
#  |      Report whether this set contains another set.
#  |
#  |  pop(...)
#  |      Remove and return an arbitrary set element.
#  |      Raises KeyError if the set is empty.
#  |
#  |  remove(...)
#  |      Remove an element from a set; it must be a member.
#  |
#  |      If the element is not a member, raise a KeyError.
#  |
#  |  symmetric_difference(...)
#  |      Return the symmetric difference of two sets as a new set.
#  |
#  |      (i.e. all elements that are in exactly one of the sets.)
#  |
#  |  symmetric_difference_update(...)
#  |      Update a set with the symmetric difference of itself and another.
#  |
#  |  union(...)
#  |      Return the union of sets as a new set.
#  |
#  |      (i.e. all elements that are in either set.)
#  |
#  |  update(...)
#  |      Update a set with the union of itself and others.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %% [markdown]
# ## 增

# %% [markdown]
# * add
# * update

# %%
help(s.add)
# Out:
# Help on built-in function add:
#
# add(...) method of builtins.set instance
#     Add an element to a set.
#
#     This has no effect if the element is already present.

# %%
s
# Out:
# {1, 2, 3}

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# 结论：当add一个已经存在的元素时，不会发生任何改变；也不会报错

# %%
help(s.update)
# Out:
# Help on built-in function update:
#
# update(...) method of builtins.set instance
#     Update a set with the union of itself and others.

# %%
s.update([3,4,5,6])         ## update 可以是元组，也可以是字符串

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
## 把一个元素(列表)转换成一个集合，怎么做呢

# %%
set().update([1,2,3,4])   ## 不过不需要这么做

# %%
set([1,3,2,4])  ## 直接给一个可迭代对象
# Out:
# {1, 2, 3, 4}

# %%
set([1,3,2,1,2,4])
# Out:
# {1, 2, 3, 4}

# %%
list(set([1,3,2,1,2,4]))  ##这样就可以对一个list去重复了！
# Out:
# [1, 2, 3, 4]

# %%
### set是无序的

# %% [markdown]
# ### 坑

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.add([1,2,3])    ## 有错误了
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-c2c8f15cf478> in <module>()
# ----> 1 s.add([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
通过hash内置函数，求出一个对象的hash

# %%
hash([1,2,3])   ## hash了一个列表；OK，报的错与以上一样
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-fb5b1b1d9906> in <module>()
# ----> 1 hash([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
hash(1)       ## 整数是可哈希的
# Out:
# 1

# %%
hash(0.1)     ## 浮点是可哈希的
# Out:
# 230584300921369408

# %%
hash('chen')   ## 字符是可哈希的
# Out:
# -3488540204367665407

# %%
hash((1,2))    ## 元组也是可哈希的
# Out:
# 3713081631934410656

# %%
hash(bytearray('chen'.encode()))   ## bytearray是不可hash的
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-a478c6447da8> in <module>()
# ----> 1 hash(bytearray('chen'.encode()))
#
# TypeError: unhashable type: 'bytearray'

# %%
hash('chen'.encode())   ## bytes是可以的
# Out:
# -3488540204367665407

# %%
hash({1,2,3})      ## set是不可哈希的
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-92b3a7769fc7> in <module>()
# ----> 1 hash({1,2,3})
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# ## 对于内置类型来说，不可变是都是可哈希的，可变的都是不可哈希的！

# %%
class A:     ## 自定义类型
    pass

# %%
a = A()

# %%
hash(a)      ## 自定义类型是可以哈希的，绝大多数
# Out:
# -9223363257903516472

# %% [markdown]
# ### 总结：列表、集合、字典是不能够做为集合的元素的！！

# %% [markdown]
# * list set bytearray dict是不可hash的（可变的）所以不能作为set的元素，通常来说，内置类型，不可变类型是可hash的，可变类型是不可hash的

# %% [markdown]
# ### 删

# %% [markdown]
# * remove
# * discard   丢弃
# * pop
# * clear

# %%
help(s.remove)
# Out:
# Help on built-in function remove:
#
# remove(...) method of builtins.set instance
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s.remove(1)

# %%
s
# Out:
# {2, 3, 4, 5, 6}

# %%
s.remove(10)   ## 不存在时，报错
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-99f2b84d3df8> in <module>()
# ----> 1 s.remove(10)
#
# KeyError: 10

# %%
help(s.discard)
# Out:
# Help on built-in function discard:
#
# discard(...) method of builtins.set instance
#     Remove an element from a set if it is a member.
#
#     If the element is not a member, do nothing.

# %%
s.discard(2)

# %%
s
# Out:
# {3, 4, 5, 6}

# %%
s.discard(10)    ## 什么也没发生，不报错   不存在时什么也没有发生

# %%
# s的结果还是{3,4,5,6}

# %%
remove删除不存在的元素会抛出KeyError, discard删除不存在的元素不会发生任何事情。

# %%
help(s.pop)
# Out:
# Help on built-in function pop:
#
# pop(...) method of builtins.set instance
#     Remove and return an arbitrary set element.
#     Raises KeyError if the set is empty.

# %%
s.pop()   ## 注意：pop是随机返回一个，无序的
# Out:
# 3

# %%
s
# Out:
# {4, 5, 6}

# %%
set().pop()    ## 当是一个空集合的时候，pop会报KeyError
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-cf82e1bf9299> in <module>()
# ----> 1 set().pop()
#
# KeyError: 'pop from an empty set'

# %% [markdown]
# *  **pop返回的元素是无序的**
# * 空集合pop时，抛出KeyError异常

# %%
help(s.clear)
# Out:
# Help on built-in function clear:
#
# clear(...) method of builtins.set instance
#     Remove all elements from this set.

# %%
s.clear()   ## 移除所有元素

# %%
s   ## 变成了一个空set
# Out:
# set()

# %%
s.clear()   ## 对一个空集合操作，就是什么也没有发生

# %%
s
# Out:
# set()

# %% [markdown]
# ### 修改 和 查找

# %% [markdown]
# 没有一个方法可以直接修改集合中的某个具体元素，集合就是一个整体！！

# %% [markdown]
# 因为没有一个方法，可以定位其中某个具体元素

# %%
for x in set('chen'):    ## 访问集合里的操作符  也可以for x in {1,2,3}:  {}里面是一个集合
    print(x)        ## 也就只能对集合的整体来操作，遍历出来，没法修改某个元素的！
                    ## set('chen') 就是把这样一个字符串转换为set
# Out:
# n
# h
# e
# c

# %%
## 集合是可迭代对象       集合也是不可变的，所以怎么能修改呢

# %%
## 也可以用以下来进行操作

# %%
'm' in set ('chen')   ## 集合可以用成员运算法 
                      ## 线性结构的成员运算时间复杂度是O(n)，集合的成员
                      ##  运算，时间复杂度是O(1)
# Out:
# False

# %%
'c' in set ('chen')
# Out:
# True

# %%
拓展知识：

O(1) 常数复杂度        ## 最快
O(logn) 对数复杂度
O(n) 线性复杂度
O(n^2) 平方复杂度
O(n^3)
O(2^n) 指数复杂度
O(n!) 阶乘复杂度   

以上性能通常是由上到下顺序的，但也不一定  到指数复杂度就很慢了，当然要看计算规模

这只是时间复杂度，还有空间复杂度。现阶段暂不用考虑！

# %% [markdown]
# ### 注：集合的应用场景非常多

# %%
### 比如去重复的场景等

# %% [markdown]
# ## 集合的集合运算

# %% [markdown]
#  * union  并集   |
#  * intersection 交集   &
#  * difference 差集   -
#  * symmetric_difference 对称差集

# %%
a = {1,2,3}
b = {2,3,4}

# %%
a
# Out:
# {1, 2, 3}

# %%
b
# Out:
# {2, 3, 4}

# %%
a.union(b)   ## 并集
# Out:
# {1, 2, 3, 4}

# %%
a.intersection(b)  ## 交集
# Out:
# {2, 3}

# %%
a.difference(b)   ## 差集
# Out:
# {1}

# %%
b.difference(a)
# Out:
# {4}

# %%
a.union(b) == b.union(a)
# Out:
# True

# %%
a.intersection(b) == b.intersection(a)
# Out:
# True

# %%
a.difference(b) == b.difference(a)
# Out:
# False

# %%
a.symmetric_difference(b)  ## 对称差集   对称差分
# Out:
# {1, 4}

# %%
a.symmetric_difference(b) == b.symmetric_difference(a)
# Out:
# True

# %%
a + b   ## python3中不能这么运算了
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-f96fb8f649b6> in <module>()
# ----> 1 a + b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a - b  ## 求差集是可以这样运算的
# Out:
# {1}

# %%
b - a
# Out:
# {4}

# %%
a & b  ## 这是交集运算
# Out:
# {2, 3}

# %%
a | b  ## 这才是并集  a或b的意思    可不是用a + b
# Out:
# {1, 2, 3, 4}

# %%
help(a)
# Out:
# Help on set object:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __ixor__(self, value, /)
#  |      Return self^=value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(...)
#  |      S.__sizeof__() -> size of S in memory, in bytes
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  add(...)
#  |      Add an element to a set.
#  |
#  |      This has no effect if the element is already present.
#  |
#  |  clear(...)
#  |      Remove all elements from this set.
#  |
#  |  copy(...)
#  |      Return a shallow copy of a set.
#  |
#  |  difference(...)
#  |      Return the difference of two or more sets as a new set.
#  |
#  |      (i.e. all elements that are in this set but not the others.)
#  |
#  |  difference_update(...)
#  |      Remove all elements of another set from this set.
#  |
#  |  discard(...)
#  |      Remove an element from a set if it is a member.
#  |
#  |      If the element is not a member, do nothing.
#  |
#  |  intersection(...)
#  |      Return the intersection of two sets as a new set.
#  |
#  |      (i.e. all elements that are in both sets.)
#  |
#  |  intersection_update(...)
#  |      Update a set with the intersection of itself and another.
#  |
#  |  isdisjoint(...)
#  |      Return True if two sets have a null intersection.
#  |
#  |  issubset(...)
#  |      Report whether another set contains this set.
#  |
#  |  issuperset(...)
#  |      Report whether this set contains another set.
#  |
#  |  pop(...)
#  |      Remove and return an arbitrary set element.
#  |      Raises KeyError if the set is empty.
#  |
#  |  remove(...)
#  |      Remove an element from a set; it must be a member.
#  |
#  |      If the element is not a member, raise a KeyError.
#  |
#  |  symmetric_difference(...)
#  |      Return the symmetric difference of two sets as a new set.
#  |
#  |      (i.e. all elements that are in exactly one of the sets.)
#  |
#  |  symmetric_difference_update(...)
#  |      Update a set with the symmetric difference of itself and another.
#  |
#  |  union(...)
#  |      Return the union of sets as a new set.
#  |
#  |      (i.e. all elements that are in either set.)
#  |
#  |  update(...)
#  |      Update a set with the union of itself and others.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
a.intersection(b)   ## 它并没有修改a    这是交集
# Out:
# {2, 3}

# %%
a   ## a 还是这样的
# Out:
# {1, 2, 3}

# %%
a.intersection_update(b)  ## 加update版本  原地修改集合，返回值为None

# %%
a
# Out:
# {2, 3}

# %%
## union(并集)没有union_update版本
## update版本的集合运算，原地修改集合，返回值为None
## 有没有update的方法，类似于Linux中的sed和sed -i命令  sed -i 直接修改原文件

# %% [markdown]
# * issuperset  是不是超集
# * issubset    是不是子集
# * isdisjoint   判断两个集合是否不相交

# %%
a = {1,2,3,4}   ## 重新定义一下

# %%
b = {3,4}

# %%
a.issuperset(b)   ## a 是不是 b 的超集
# Out:
# True

# %%
b.issubset(a)  ## b 是不是 a 的子集
# Out:
# True

# %%
b.issuperset(a)
# Out:
# False

# %%
a.issuperset(a)   ## a也是a的超集
# Out:
# True

# %%
a.issubset(a)   ## a也是a的子集   跟数学上的定义相同
# Out:
# True

# %% [markdown]
# isdisjoint 判断两个集合是否不相交

# %%
a.isdisjoint(b)    ## 判断两个集合是否(有)不相交
# Out:
# False

# %%
a.isdisjoint({5,6})
# Out:
# True

# %%
a.isdisjoint([7,8])
# Out:
# True

# %% [markdown]
# ### 集合的应用      集合非常有用

# %% [markdown]
# * 元素需要唯一而对顺序没有需求

# %%
hosts = set(user_input.splitlines())  ## 获取用户主机  这是一种用法

# %% [markdown]
# * 我们需要集合运算时

# %%
in_progress_hosts = hosts - complete_hosts   ## 获取还未执行的机器列表

# %%
hosts = input_a | input_b | input_b     ## 从多个地方有多个用户来输入，能得到total的

# %%
# 以上，集合就派上用场了     能进python 标准库的，都应该是有用的

# %%
还可对多个文件目录去重

# %% [markdown]
# ### 其它的方法，如copy，直接help查看吧

# %% [markdown]
# # 字典

# %% [markdown]
# 字典是一个key value结构     字典的用途要比集合广泛

# %%
d = dict()        ## 这两个是初始化空字典

# %%
d = {}

# %%
d = {'a':1, 'b':2}

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# 字典的value可以是任意值

# %% [markdown]
# 字典的key必须是可hash的值

# %% [markdown]
# 字典的key是唯一的

# %% [markdown]
# ## 字典的下标操作

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d['a']
# Out:
# 1

# %%
d['a'] = 123

# %%
d
# Out:
# {'a': 123, 'b': 2}

# %%
d['c']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-3e4d85f12902> in <module>()
# ----> 1 d['c']
#
# KeyError: 'c'

# %%
d['c'] = 345

# %%
d
# Out:
# {'a': 123, 'b': 2, 'c': 345}

# %% [markdown]
# 字典是可变的！！  原地修改

# %%
d['a':'c']   ## 字典没有切片操作！
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-19f90c2f886b> in <module>()
# ----> 1 d['a':'c']
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# ## 增加 和 修改

# %%
d['d']=23

# %%
d
# Out:
# {'a': 123, 'b': 2, 'c': 345, 'd': 23}

# %%
help(d)
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Returns a new dict with keys from iterable and values equal to value.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
help(d.update)
# Out:
# Help on built-in function update:
#
# update(...) method of builtins.dict instance
#     D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#     If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#     If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#     In either case, this is followed by: for k in F:  D[k] = F[k]

# %%
d
# Out:
# {'a': 123, 'b': 2, 'c': 345, 'd': 23}

# %%
d.update({'f':111, 'e':222})

# %%
d
# Out:
# {'a': 123, 'b': 2, 'c': 345, 'd': 23, 'e': 222, 'f': 111}

# %%
d.update([('g',333),('h',4444)])       ## list也OK 因为它是一对一对的元组

# %%
d
# Out:
# {'a': 123, 'b': 2, 'c': 345, 'd': 23, 'e': 222, 'f': 111, 'g': 333, 'h': 4444}

# %%
d.update([1,2,3])  ## 这样的list就不行
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-6996aedee5de> in <module>()
# ----> 1 d.update([1,2,3])
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
d.update([('i',111,222)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-909e6da1383f> in <module>()
# ----> 1 d.update([('i',111,222)])
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required

# %%
d.update(i=555)

# %%
d
# Out:
# {'a': 123,
#  'b': 2,
#  'c': 345,
#  'd': 23,
#  'e': 222,
#  'f': 111,
#  'g': 333,
#  'h': 4444,
#  'i': 555}

# %% [markdown]
# update 的参数可以是以下几种情况：
#
# * 字典   如：d.update({'f':111, 'e':222})
# * 由***二元组***构成的可迭代对象，其它的可迭代对象是不允许的  如：d.update([('g',333),('h',4444)])
# * 关键字参数    如：d.update(i=555)

# %%
d.update([['h',50]])  这样也是可以的 (里面两个中括号) 和这样  d.update(j=70,k=80)

# %%
d
# Out:
# {'a': 123,
#  'b': 2,
#  'c': 345,
#  'd': 23,
#  'e': 222,
#  'f': 111,
#  'g': 333,
#  'h': 4444,
#  'i': 555}

# %%
d.update(a=1)    ## 修改

# %%
d
# Out:
# {'a': 1,
#  'b': 2,
#  'c': 345,
#  'd': 23,
#  'e': 222,
#  'f': 111,
#  'g': 333,
#  'h': 4444,
#  'i': 555}

# %% [markdown]
# update时，如果key相同，会覆盖原来的value

# %%
字典中关于增加的，只有update操作！

# %% [markdown]
# ## 删除

# %% [markdown]
# * pop
# * popitem
# * clear

# %%
help(d.pop)
# Out:
# Help on built-in function pop:
#
# pop(...) method of builtins.dict instance
#     D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#     If key is not found, d is returned if given, otherwise KeyError is raised

# %%
d
# Out:
# {'a': 1,
#  'b': 2,
#  'c': 345,
#  'd': 23,
#  'e': 222,
#  'f': 111,
#  'g': 333,
#  'h': 4444,
#  'i': 555}

# %%
d.pop('i')
# Out:
# 555

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 345, 'd': 23, 'e': 222, 'f': 111, 'g': 333, 'h': 4444}

# %%
d.pop('i')   ## 再pop i 就出错了
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-9abd3bb9e919> in <module>()
# ----> 1 d.pop('i')
#
# KeyError: 'i'

# %%
d.pop('i', -1)  ## 给了一个默认值
# Out:
# -1

# %%
help(d.popitem)
# Out:
# Help on built-in function popitem:
#
# popitem(...) method of builtins.dict instance
#     D.popitem() -> (k, v), remove and return some (key, value) pair as a
#     2-tuple; but raise KeyError if D is empty.

# %%
d.popitem()   ## 随机弹出了一个KV对   用的比较少  pop用的较多
# Out:
# ('g', 333)

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 345, 'd': 23, 'e': 222, 'f': 111, 'h': 4444}

# %% [markdown]
# popitem 随机返回一个KV对

# %%
d.clear()

# %%
d
# Out:
# {}

# %% [markdown]
# ### 访问

# %%
d = {'a':1, 'b':2}

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d['a']       ## 可以用过此方法访问
# Out:
# 1

# %%
help(d.get)   ## get方法      此方法属于关键应用，掌握！
# Out:
# Help on built-in function get:
#
# get(...) method of builtins.dict instance
#     D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.

# %%
d.get('a')        ## 也可以用此方法
# Out:
# 1

# %%
d.get('c')   ## 没有的，无返回  返回的是None

# %%
d.get('c',123)  ## 返回的是默认值
# Out:
# 123

# %%
help(d.setdefault)
# Out:
# Help on built-in function setdefault:
#
# setdefault(...) method of builtins.dict instance
#     D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D

# %%
d.setdefault('c',123)      ## 不存在的时候，设置一个默认值，存在则返回原值，不存在则返回默认值
                           ## 要针对每个KEY来设置，所以用的不多
# Out:
# 123

# %%
d.get('c')       ## 当用get或是下标访问的时候，就会返回默认值
# Out:
# 123

# %%
d['c']          ## 当用get或是下标访问的时候，就会返回默认值
# Out:
# 123

# %%
d['c']=3

# %%
d['c']
# Out:
# 3

# %%
d.pop('c')
# Out:
# 3

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d.get('c')

# %%
d['c']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-3e4d85f12902> in <module>()
# ----> 1 d['c']
#
# KeyError: 'c'

# %%
from collections import defaultdict   ## collections可能是标准库

# %%
help(defaultdict)
# Out:
# Help on class defaultdict in module collections:
#
# class defaultdict(builtins.dict)
#  |  defaultdict(default_factory[, ...]) --> dict with default factory
#  |
#  |  The default factory is called without arguments to produce
#  |  a new value when a key is not present, in __getitem__ only.
#  |  A defaultdict compares equal to a dict with the same items.
#  |  All remaining arguments are treated the same as if they were
#  |  passed to the dict constructor, including keyword arguments.
#  |
#  |  Method resolution order:
#  |      defaultdict
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __copy__(...)
#  |      D.copy() -> a shallow copy of D.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __missing__(...)
#  |      __missing__(key) # Called by __getitem__ for missing key; pseudo-code:
#  |      if self.default_factory is None: raise KeyError((key,))
#  |      self[key] = value = self.default_factory()
#  |      return value
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  default_factory
#  |      Factory for default value called by __missing__().
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.dict:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Returns a new dict with keys from iterable and values equal to value.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from builtins.dict:
#  |
#  |  __hash__ = None

# %%
dd = defaultdict(list)       ## list是工场方法

# %%
dd.get('x')

# %%
dd['x']   ## 用下标访问
# Out:
# []

# %%
defaultdict 只是对 dict 的一个增强，只是介绍一下!

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d.setdefault('c',123)
# Out:
# 123

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 123}

# %%
set 和 setdefault 其实没什么区别，区别就在于setdefault会返回回来

# %%
d.setdefault('c',222)  ## 如果没有c，则创建它，有，则不修改它
# Out:
# 123

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 123}

# %%
## 实际上，setdefault 应该是在增加 修改那里讲的；用的场景非常少；
## 主要多线程编程时可能会用。

# %% [markdown]
# *** 这课重点主要是get与下标操作的区别！

# %% [markdown]
# ### 遍历

# %%
字典的遍历

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 123}

# %%
for item in d :        ## 遍历了key
    print (item)
# Out:
# a
# b
# c

# %%
help(d.keys)
# Out:
# Help on built-in function keys:
#
# keys(...) method of builtins.dict instance
#     D.keys() -> a set-like object providing a view on D's keys

# %%
d.keys()       ## 它就是一个生成器
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
for k in d.keys():       ## 就可以用此方式来遍历字典
    print('{} => {}'.format(k,d[k]))
# Out:
# a => 1
# b => 2
# c => 123

# %%
dk = d.keys()

# %%
help(dk)
# Out:
# Help on dict_keys object:
#
# class dict_keys(object)
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  isdisjoint(...)
#  |      Return True if the view and the given iterable have a null intersection.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
dk - {'a','b'}   ## 减去一个set(set是集合)
# Out:
# {'c'}

# %%
dk & {'a','b'}      ## 可以跟set一样，做交集
# Out:
# {'a', 'b'}

# %%
dk
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
dk | {'a','b'}      ## 并集
# Out:
# {'a', 'b', 'c'}

# %%
dk ^ {'b','c','d'}  ## 对称差
# Out:
# {'a', 'd'}

# %% [markdown]
# keys也是无序的

# %%
help(d.values)
# Out:
# Help on built-in function values:
#
# values(...) method of builtins.dict instance
#     D.values() -> an object providing a view on D's values

# %%
d.values()
# Out:
# dict_values([1, 2, 123])

# %%
for v in d.values():  ## 不关注key的时候，将values输出
    print(v)
# Out:
# 1
# 2
# 123

# %%
dv = d.values()

# %%
help(dv)     ## 查看values有什么属性
# Out:
# Help on dict_values object:
#
# class dict_values(object)
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).

# %% [markdown]
# value也是不可变的，类似于元组，但并没有元组那么多方法

# %%
len(dv)
# Out:
# 3

# %% [markdown]
# 不过，更多的时候还是希望返回key,value

# %%
d.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 123)])

# %%
help(d.items)
# Out:
# Help on built-in function items:
#
# items(...) method of builtins.dict instance
#     D.items() -> a set-like object providing a view on D's items

# %%
for k, v in d.items():   ## 这是用的最多的方法，可以遍历字典了！！
    print('{} => {}'.format(k,v))   ## items返回kv对     print (k,v)也可
# Out:
# a => 1
# b => 2
# c => 123

# %%
di = d.items()

# %%
help(di)
# Out:
# Help on dict_items object:
#
# class dict_items(object)
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  isdisjoint(...)
#  |      Return True if the view and the given iterable have a null intersection.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %% [markdown]
# ### keys values items get 是字典里用的最多最多的东西！

# %%
## keys只返回key的集合，而items是返回k,v对的集合！！

# %%
enumerate(d)

# %%
for k,v in enumerate(d):  ## 返回的索引加上key，与items的产出效果不一样的
    print('{} => {}'.format(k,v))  ## 注意这里的索引是由enumerate来加的
# Out:
# 0 => a
# 1 => b
# 2 => c

# %%
for k in d:
    print(k)
# Out:
# a
# b
# c

# %% [markdown]
# 字典是无序的结构。  无论是通过key或values来遍历，都是无序的

# %% [markdown]
# 那么，怎么让字典有序呢？

# %%
from collections import OrderedDict

# %%
help(OrderedDict)  ## OrderedDict可以让字典有序   用的也不多，只是维持顺序的
# Out:
# Help on class OrderedDict in module collections:
#
# class OrderedDict(builtins.dict)
#  |  Dictionary that remembers insertion order
#  |
#  |  Method resolution order:
#  |      OrderedDict
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(...)
#  |      od.__reversed__() <==> reversed(od)
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      od.clear() -> None.  Remove all items from od.
#  |
#  |  copy(...)
#  |      od.copy() -> a shallow copy of od
#  |
#  |  fromkeys(...) from builtins.type
#  |      OD.fromkeys(S[, v]) -> New ordered dictionary with keys from S.
#  |      If not specified, the value defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  move_to_end(...)
#  |      Move an existing element to the end (or beginning if last==False).
#  |
#  |      Raises KeyError if the element does not exist.
#  |      When last=True, acts like a fast version of self[key]=self.pop(key).
#  |
#  |  pop(...)
#  |      od.pop(k[,d]) -> v, remove specified key and return the corresponding
#  |      value.  If key is not found, d is returned if given, otherwise KeyError
#  |      is raised.
#  |
#  |  popitem(...)
#  |      od.popitem() -> (k, v), return and remove a (key, value) pair.
#  |      Pairs are returned in LIFO order if last is true or FIFO order if false.
#  |
#  |  setdefault(...)
#  |      od.setdefault(k[,d]) -> od.get(k,d), also set od[k]=d if k not in od
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.dict:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.

# %%
od = OrderedDict()

# %%
od['a'] = 1

# %%
od['b'] = 2

# %%
od['c'] = 3

# %%
od.keys()    ## 它会保持插入的顺序   这是OrderdDict与字典的唯一区别所在
# Out:
# odict_keys(['a', 'b', 'c'])

# %%
for k,v in od.items():
    print(k,v)
# Out:
# a 1
# b 2
# c 3

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 123}

# %%
for k,v in d.items():     ## 通过value查找key
    if v == 123 :
        print(k)
        break    ## 不break可以找出所有的，有break只能找出其中一个
                  ## 因为是无序的，不知道先找出哪一个，而且值是可能重复的
# Out:
# c

# %%
for k,v in d.items():
    print(k,v)
# Out:
# a 1
# b 2
# c 123

# %% [markdown]
# 以上是根据value来找key的一种方案

# %% [markdown]
# ### 以上字典的常用方法都讲了！          练习15分钟

# %% [markdown]
# ### 其它方法

# %%
dir(d)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
help(d.copy)
# Out:
# Help on built-in function copy:
#
# copy(...) method of builtins.dict instance
#     D.copy() -> a shallow copy of D

# %%
help(d.fromkeys)
# Out:
# Help on built-in function fromkeys:
#
# fromkeys(iterable, value=None, /) method of builtins.type instance
#     Returns a new dict with keys from iterable and values equal to value.

# %%
d.fromkeys([1,2,3])        ## fromkeys通常用于初始化一个字典，给初值
# Out:
# {1: None, 2: None, 3: None}

# %%
d.fromkeys([1,2,3], False)
# Out:
# {1: False, 2: False, 3: False}

# %%
hosts = {1,2,3}

# %%
dict.fromkeys(hosts, False)
# Out:
# {1: False, 2: False, 3: False}

# %%
字典已经讲完。

# %% [markdown]
# ### 补充：

# %%
做成员运算时，列表的效率和列表的规模有关！   ## 规模小的时候，非常好；规模超大的时候，效果非常不好！大规模应先转换为集合
做成员运算时，集合的效率和集合的规模无关！   ## 成员运算就是 什么 in 什么

# %% [markdown]
# 成员运算：
# * 集合O(1)
# * 列表（线性结构）O(n)

# %%
# %%timeit  ## 这是ipython 提供的功能  ， python本身没有这个功能

# %%
交集：

# %%
s1 = {1,2,3}

# %%
s2 = {2,3,4}

# %%
s1.intersection(s2)        ## 不修改原来的两个集合，返回新的集合
# Out:
# {2, 3}

# %%
s1.intersection_update(s2)          ## 带_update版本，原地修改，返回None,  等效于 s1 = s1.intersection(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s2
# Out:
# {2, 3, 4}

# %% [markdown]
# ### 补集的定义是依赖于全集的！所以没有补集的。

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s3 = {1,2}

# %%
s4 = {3,4}

# %%
s3.isdisjoint(s4)     ## 判断两个集合是否有交集，如果有交集返回False,没有则返回True
# Out:
# True

# %% [markdown]
# ### 集合的用法

# %% [markdown]
# 例如：有一个api,它要有认证，并且有一定权限才可以访问，例如要求满足权限A,B,C中任意一项，有一个用户具有权限B,C,D,
# 那么此用户是否有权限访问此api?

# %%
这就可以用到  s1.isdisjoint(s2)           ## 判断两个集合是否有交集，如果有交集返回False,没有则返回True

# %% [markdown]
# 有一个任务列表，存储全部的任务，有一个列表，存储已经完成的任务，找出未完成的任务

# %% [markdown]
# 所以，通过例子，集合是非常有用的！

# %%
## list、set、bytearray 这些都不能是集合的元素！不可hash

# %%
## 可变类型不能成为集合的元素，实际这句话并不算太对！

# %% [markdown]
# 集合元素必须可hash  ，这是重点

# %%
hash(b'abc')
# Out:
# 1315609293003706833

# %%
hash(1)   ## 一个整数是可hash的
# Out:
# 1

# %%
hash(0)
# Out:
# 0

# %%
hash([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-fb5b1b1d9906> in <module>()
# ----> 1 hash([1,2,3])
#
# TypeError: unhashable type: 'list'

# %%
hash((1,2,3))
# Out:
# 2528502973977326415

# %% [markdown]
# 目前我们所知道的所有的可变的类型，都是不可hash的，所有的不可变类型，都是可hash的！

# %% [markdown]
# 目前只有 list,bytearray,set是不可hash的！

# %% [markdown]
# ### 字典：

# %%
d = dict.fromkeys(range(5))     ## 传入的可迭代元素为key,值为None

# %%
d
# Out:
# {0: None, 1: None, 2: None, 3: None, 4: None}

# %%
d = dict.fromkeys(range(5),'abc')     ## 传入的可迭代对象的元素为key,值为'abc'

# %%
d
# Out:
# {0: 'abc', 1: 'abc', 2: 'abc', 3: 'abc', 4: 'abc'}

# %%
d = dict([('a',1),('b',2)])   ## 可迭代对象的元素必须是一个二元组，二元组的第0个元素是key,第1个元素是value

# %%
d
# Out:
# {'a': 1, 'b': 2}

# %%
d.pop('b','haha')
# Out:
# 2

# %%
d
# Out:
# {'a': 1}

# %%
d.pop('b','haha')
# Out:
# 'haha'

# %%
d.pop('b')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-d3ffcf2e5433> in <module>()
# ----> 1 d.pop('b')
#
# KeyError: 'b'

# %%
d
# Out:
# {'a': 1}

# %%
d.items()
# Out:
# dict_items([('a', 1)])

# %%
type(d.items())          ## 在python2里，这些返回的都是list   ，它们会复制出一块内存
                         ## python3里是可迭代对象(类似生成器)，它并不会复制出一块内存
# Out:
# dict_items

# %%
type(d.keys())
# Out:
# dict_keys

# %%
type(d.values())
# Out:
# dict_values

# %%
有个setdefault方法，原形如下：

# %%
def setdefault(d,k,default=None):
    value = d.get(k,default)
    d[k] = value
    return value

# %%
字典的key需要可hash!

# %% [markdown]
# ### 有序字典

# %%
from collections import OrderedDict

# %%
d = OrderedDict()

# %%
d[0] = 3

# %%
d[3] = 4

# %%
d[1] = 5

# %%
d                 ## 根据输入的顺序
# Out:
# OrderedDict([(0, 3), (3, 4), (1, 5)])

# %%
for k,v in d.items():
    print(k,v)
# Out:
# 0 3
# 3 4
# 1 5

# %% [markdown]
# 有序字典，会保持插入顺序。

# %%
d
# Out:
# OrderedDict([(0, 3), (3, 4), (1, 5)])

# %% [markdown]
# ### 还有一个扩展是默认字典，也是有需求的，使用也是广泛的！

# %%
## 此处没有示例！
